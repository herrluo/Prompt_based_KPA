# %% [markdown]
# ### Manufacturing data set

# %%
import pandas as pd
df = pd.read_csv('./data/ground_truth.csv')
print(df)
predict_df = pd.read_csv('./result/1by1+predictions.csv')
print(predict_df)
# Out:
#                                               topic  \
# 0     Assisted suicide should be a criminal offence
# 1     Assisted suicide should be a criminal offence
# 2     Assisted suicide should be a criminal offence
# 3     Assisted suicide should be a criminal offence
# 4     Assisted suicide should be a criminal offence
# ...                                             ...
# 5545           The USA is a good country to live in
# 5546           The USA is a good country to live in
# 5547           The USA is a good country to live in
# 5548           The USA is a good country to live in
# 5549           The USA is a good country to live in
#
#                                                argument  \
# 0     a cure or treatment may be discovered shortly ...
# 1     A patient should be able to decide when they h...
# 2     a person has the right to end their suffering ...
# 3     a person should have the dignity to choose how...
# 4     a person should have the right to be able to c...
# ...                                                 ...
# 5545  Yes, since he has great economic stability, a ...
# 5546  Yes, since he has great economic stability, a ...
# 5547  Yes, since he has great economic stability, a ...
# 5548  Yes, they have a stable economy and for that r...
# 5549   You have real opportunities to improve your life
#
#                                               key_point  stance  label
# 0     Assisted suicide should not be allowed because...       1      1
# 1     People should have the freedom to choose to en...      -1      1
# 2                    Assisted suicide reduces suffering      -1      1
# 3     People should have the freedom to choose to en...      -1      1
# 4     People should have the freedom to choose to en...      -1      1
# ...                                                 ...     ...    ...
# 5545              The US has a great environment/nature       1      1
# 5546  The US has a good economy/high standard of living       1      1
# 5547    The US has a good health and education systems        1      1
# 5548  The US has a good economy/high standard of living       1      1
# 5549  The US offers great opportunities for individuals       1      1
#
# [5550 rows x 5 columns]
#                                               topic  stance  \
# 0     Assisted suicide should be a criminal offence       1
# 1     Assisted suicide should be a criminal offence       1
# 2     Assisted suicide should be a criminal offence       1
# 3     Assisted suicide should be a criminal offence       1
# 4     Assisted suicide should be a criminal offence       1
# ...                                             ...     ...
# 7233           The USA is a good country to live in       0
# 7234           The USA is a good country to live in       0
# 7235           The USA is a good country to live in       0
# 7236           The USA is a good country to live in       0
# 7237           The USA is a good country to live in       0
#
#                                                argument  \
# 0     a cure or treatment may be discovered shortly ...
# 1     allow assisted suicide could allow unscrupulou...
# 2     Allowing assisted suicide would enable greedy ...
# 3     an assisted suicide is just another way to mur...
# 4     and who defines reasonable certainty, how many...
# ...                                                 ...
# 7233  United States the country where the poor have ...
# 7234  USA is not a good country to live in because q...
# 7235           USA still presents a big racial problem.
# 7236  We are a nation that is crowded with legal and...
# 7237  Years of bad leaders are causing chaos in the ...
#
#                                               key_point
# 0     Assisted suicide could lead to premature loss ...
# 1     Allowing assisted suicide could potentially en...
# 2     The legalization of assisted suicide may lead ...
# 3     Assisted suicide equates to murder, regardless...
# 4     The certainty of prognosis in medicine is not ...
# ...                                                 ...
# 7233  The US does not provide adequate opportunities...
# 7234  The cost of quality college education in the U...
# 7235  The USA has significant racial issues to conte...
# 7236  The USA attracts both legal and illegal immigr...
# 7237  Despite the chaos caused by years of mismanage...
#
# [7238 rows x 4 columns]

# %%
predict_df_header = predict_df.columns
print(predict_df_header)
# Out:
# Index(['topic', 'stance', 'argument', 'key_point'], dtype='object')

# %%
def remove_duplicate_sentences(sentences):
    unique_sentences = []
    seen_sentences = set()

    for sentence in sentences:
        if sentence not in seen_sentences:
            unique_sentences.append(sentence)
            seen_sentences.add(sentence)

    return unique_sentences

# %%
ArgKP2021_topics = [
    "Assisted suicide should be a criminal offence",
    "Homeschooling should be banned",
    "The vow of celibacy should be abandoned",
    "We should abandon marriage",
    "We should abandon the use of school uniform",
    "We should abolish capital punishment",
    "We should abolish intellectual property rights",
    "We should abolish the right to keep and bear arms",
    "We should adopt an austerity regime",
    "We should adopt atheism",
    "We should adopt libertarianism",
    "We should ban human cloning",
    "We should ban private military companies",
    "We should ban the use of child actors",
    "We should close Guantanamo Bay detention camp",
    "We should end affirmative action",
    "We should end mandatory retirement",
    "We should fight for the abolition of nuclear weapons",
    "We should fight urbanization",
    "We should introduce compulsory voting",
    "We should legalize cannabis",
    "We should legalize prostitution",
    "We should legalize sex selection",
    "We should prohibit flag burning",
    "We should prohibit women in combat",
    "We should subsidize journalism",
    "We should subsidize space exploration",
    "We should subsidize vocational education",
    "Routine child vaccinations should be mandatory",
    "Social media platforms should be regulated by the government",
    "The USA is a good country to live in"
]

predict_KPs = []
for topic in ArgKP2021_topics:
    topic_p_df = predict_df[(predict_df['topic'] == topic) & (predict_df['stance'] == 1)]
    topic_n_df = predict_df[(predict_df['topic'] == topic) & (predict_df['stance'] == 0)]
    topic_p_predicts = list(topic_p_df['key_point'].values)
    topic_n_predicts = list(topic_n_df['key_point'].values)
    deduplicated_topic_p_arguments = remove_duplicate_sentences(topic_p_predicts)
    deduplicated_topic_n_arguments = remove_duplicate_sentences(topic_n_predicts)
    predict_KPs.append(deduplicated_topic_p_arguments)
    predict_KPs.append(deduplicated_topic_n_arguments)
print("list length: " + str(len(predict_KPs)))
total_kps = 0
for kps in predict_KPs:
    total_kps += len(kps)
    print(len(kps))
print("total kps: " + str(total_kps))
# Out:
# list length: 62
# 125
# 121
# 115
# 129
# 122
# 112
# 125
# 111
# 116
# 118
# 123
# 109
# 91
# 123
# 110
# 122
# 126
# 108
# 105
# 123
# 124
# 113
# 122
# 123
# 125
# 106
# 123
# 121
# 127
# 113
# 119
# 108
# 120
# 78
# 116
# 80
# 127
# 106
# 114
# 127
# 137
# 109
# 132
# 97
# 118
# 126
# 99
# 118
# 107
# 130
# 118
# 110
# 132
# 115
# 128
# 95
# 168
# 108
# 134
# 99
# 143
# 66
# total kps: 7215

# %% [markdown]
# ### Calculate cosine similarity with Bert embedding

# %%
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import itertools

# Load pre-trained BERT model and tokenizer
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)


def sentence_relevance_test(sentences):
    # Tokenize and convert sentences to BERT embeddings
    encoded_input = tokenizer(sentences, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Extract the embeddings from the model output
    sentence_embeddings = model_output.last_hidden_state.mean(dim=1).numpy()

    # Calculate cosine similarity between each pair of sentences
    pairs = list(itertools.combinations(range(len(sentences)), 2))

    for pair in pairs:
        idx1, idx2 = pair
        similarity_score = cosine_similarity([sentence_embeddings[idx1]], [sentence_embeddings[idx2]])[0][0]
        print(f"Similarity between Sentence {idx1 + 1} and Sentence {idx2 + 1}: {similarity_score}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
print(predict_KPs[0])
# Out:
# ['The potential discovery of a cure or treatment shortly after a life has been ended unnecessarily.', 'Assisted suicide could potentially lead to exploitation by greedy relatives who may use it for financial benefits.', "The user views assisted suicide as equivalent to murder, regardless of the person's consent, placing moral responsibility on the one who aids in the act.", "The user questions the concept of 'reasonable certainty' and argues against ending life as a solution, highlighting that many people recover due to alternative treatments or medical advances. They also emphasize on the ethical implications of involvement of others in such decisions.", "The view that every individual involved in causing another person's death should face legal penalties.", 'The potential for abuse and exploitation of assisted suicide by those seeking personal gain from sick or ill relatives serves as a reason to prohibit it.', 'Potential misuse of assisted suicide, with individuals possibly being pressured or encouraged to end their lives prematurely.', 'Assisted suicide contradicts the medical oath of causing no harm and lacks oversight, leaving patients to face death alone after being prescribed lethal drugs.', 'Assisted suicide is equated with murder and is deemed illegal, thus it should be treated in the same manner.', 'Assisted suicide is viewed as a criminal act and those who engage in it should face legal consequences, including imprisonment.', 'Assisted suicide is considered a crime due to the deliberate intention to end a human life.', 'The user believes that assisted suicide equates to murder and should be legally punishable as a crime.', 'The user believes that assisted suicide is equivalent to murder and should be legally punishable as a crime.', 'The user believes that assisted suicide is equivalent to murder and argues that it should not be permitted.', 'Assisted suicide contradicts the oath taken by doctors.', 'Assisted suicide is viewed as a type of homicide.', 'Assisted suicide is considered a form of murder by the user.', 'User equates assisted suicide with murder and believes it should be legally treated the same way.', 'The user equates assisted suicide with murder and argues that since murder is illegal, so should assisted suicide be.', 'The user equates assisted suicide with murder.', 'The user views assisted suicide as a form of aiding in killing, which they believe should be interpreted as a criminal offense.', 'Assisted suicide is equated to being an accessory to murder.', 'The user believes assisted suicide is equivalent to murder and should be penalized as such.', 'Assisted suicide can be susceptible to misuse, as it can be challenging to precisely understand the intentions of the individual seeking assistance, making it potentially advantageous for individuals with vested interests.', 'Assisted suicide can be misused due to the difficulty in accurately interpreting the intentions of the individual, thereby making it susceptible to manipulation by those with vested interests.', "Assisted suicide involves ending a person's life upon their request.", 'The user believes that assisted suicide equates to murder, which constitutes it as an illegal act.', 'The user believes that assisted suicide is equivalent to murder and should be classified as a criminal offense.', 'The user believes that assisted suicide equates to murder, viewing the doctor as provider of the means for ending life.', 'The user believes that assisted suicide is not just unethical but a form of murder and should be deemed a criminal act.', "The user argues that assisted suicide is equivalent to murder as it allows one human to legally end another's life, and it should therefore be prohibited to prevent any person from causing another's death.", 'The user asserts that assisted suicide equates to murder and advocates for it to be legally classified as a criminal offence.', 'The user equates assisted suicide with murder or homicide.', 'Assisted suicide i ...

# %%
print(sentence_relevance_test(predict_KPs[0]))
# Out:
# Similarity between Sentence 1 and Sentence 2: 0.78702712059021
# Similarity between Sentence 1 and Sentence 3: 0.7449733018875122
# Similarity between Sentence 1 and Sentence 4: 0.758685827255249
# Similarity between Sentence 1 and Sentence 5: 0.8182483315467834
# Similarity between Sentence 1 and Sentence 6: 0.798798143863678
# Similarity between Sentence 1 and Sentence 7: 0.8017703294754028
# Similarity between Sentence 1 and Sentence 8: 0.7935909032821655
# Similarity between Sentence 1 and Sentence 9: 0.7456387281417847
# Similarity between Sentence 1 and Sentence 10: 0.7539781928062439
# Similarity between Sentence 1 and Sentence 11: 0.8125429153442383
# Similarity between Sentence 1 and Sentence 12: 0.7569330930709839
# Similarity between Sentence 1 and Sentence 13: 0.7573435306549072
# Similarity between Sentence 1 and Sentence 14: 0.7319722175598145
# Similarity between Sentence 1 and Sentence 15: 0.7184835076332092
# Similarity between Sentence 1 and Sentence 16: 0.7160773277282715
# Similarity between Sentence 1 and Sentence 17: 0.7261520624160767
# Similarity between Sentence 1 and Sentence 18: 0.7455379366874695
# Similarity between Sentence 1 and Sentence 19: 0.731318473815918
# Similarity between Sentence 1 and Sentence 20: 0.6998163461685181
# Similarity between Sentence 1 and Sentence 21: 0.7310266494750977
# Similarity between Sentence 1 and Sentence 22: 0.7379747629165649
# Similarity between Sentence 1 and Sentence 23: 0.7497250437736511
# Similarity between Sentence 1 and Sentence 24: 0.7521669268608093
# Similarity between Sentence 1 and Sentence 25: 0.7565741539001465
# Similarity between Sentence 1 and Sentence 26: 0.7760215997695923
# Similarity between Sentence 1 and Sentence 27: 0.7421523332595825
# Similarity between Sentence 1 and Sentence 28: 0.7440953254699707
# Similarity between Sentence 1 and Sentence 29: 0.7804432511329651
# Similarity between Sentence 1 and Sentence 30: 0.7548357248306274
# Similarity between Sentence 1 and Sentence 31: 0.7616729736328125
# Similarity between Sentence 1 and Sentence 32: 0.7399985790252686
# Similarity between Sentence 1 and Sentence 33: 0.7303992509841919
# Similarity between Sentence 1 and Sentence 34: 0.7711306810379028
# Similarity between Sentence 1 and Sentence 35: 0.7135413289070129
# Similarity between Sentence 1 and Sentence 36: 0.7732826471328735
# Similarity between Sentence 1 and Sentence 37: 0.7989523410797119
# Similarity between Sentence 1 and Sentence 38: 0.7804499268531799
# Similarity between Sentence 1 and Sentence 39: 0.7191867828369141
# Similarity between Sentence 1 and Sentence 40: 0.7385867834091187
# Similarity between Sentence 1 and Sentence 41: 0.7949448823928833
# Similarity between Sentence 1 and Sentence 42: 0.7464544177055359
# Similarity between Sentence 1 and Sentence 43: 0.7624631524085999
# Similarity between Sentence 1 and Sentence 44: 0.7611308097839355
# Similarity between Sentence 1 and Sentence 45: 0.7312851548194885
# Similarity between Sentence 1 and Sentence 46: 0.7900117039680481
# Similarity between Sentence 1 and Sentence 47: 0.7808897495269775
# Similarity between Sentence 1 and Sentence 48: 0.7580327987670898
# Similarity between Sentence 1 and Sentence 49: 0.7775881290435791
# Similarity between Sentence 1 and Sentence 50: 0.7519930601119995
# Similarity between Sentence 1 and Sentence 51: 0.7625260353088379
# Similarity between Sentence 1 and Sentence 52: 0.7866911888122559
# Similarity between Sentence 1 and Sentence 53: 0.7554700374603271
# Similarity between Sentence 1 and Sentence 54: 0.7717107534408569
# Similarity between Sentence 1 and Sentence 55: 0.7910072803497314
# Similarity between Sentence 1 and Sentence 56: 0.7858972549438477
# Similarity between Sentence 1 and Sentence 57: 0.761570155620575
# Similarity between Sentence 1 and Sentence 58: 0.729127049446106
# Similarity between Sentence 1 and Sentence 59: 0.7512741088867188
# Similarity between Sentence 1 and Sentence 60: 0.751624345779419
# Similarity between Sentence 1 and Sentence 61: 0.7884964942932129
# Similarity between Sentence 1 and Sentence 62: 0.7834227681159973
# Similarity between Sentence 1 and Sentence 63: 0.7887802720069885
# Similarity between Sentence 1 and Sentence 64: 0.804200291633606
# Similarity between Sentence 1 and Sentence 65: 0.7808877825737
# Similarity between Sentence 1 and Sentence 66: 0.7601232528686523
# Similarity between Sentence 1 and Sentence 67: 0.7188637256622314
# Similarity between Sentence 1 and Sentence 68: 0.7247031331062317
# Similarity between Sentence 1 and Sentence 69: 0.7656139135360718
# Similarity between Sentence 1 and Sentence 70: 0.7592008709907532
# Similarity between Sentence 1 and Sentence 71: 0.779784619808197
# Similarity between Sentence 1 and Sentence 72: 0.7565464377403259
# Similarity between Sentence 1 and Sentence 73: 0.7991862893104553
# Similarity between Sentence 1 and Sentence 74: 0.7600581049919128
# Similarity between Sentence 1 and Sentence 75: 0.7334680557250977
# Similarity between Sentence 1 and Sentence 76: 0.7379200458526611
# Similarity between Sentence 1 and Sentence 77: 0.7536513805389404
# Similarity between Sentence 1 and Sentence 78: 0.7979012131690979
# Similarity between Sentence 1 and Sentence 79: 0.7584051489830017
# Similarity between Sentence 1 and Sentence 80: 0.7144608497619629
# Similarity between Sentence 1 and Sentence 81: 0.7842391729354858
# Similarity between Sentence 1 and Sentence 82: 0.780397891998291
# Similarity between Sentence 1 and Sentence 83: 0.7602053284645081
# Similarity between Sentence 1 and Sentence 84: 0.7893311977386475
# Similarity between Sentence 1 and Sentence 85: 0.757718563079834
# Similarity between Sentence 1 and Sentence 86: 0.7816084623336792
# Similarity between Sentence 1 and Sentence 87: 0.791412353515625
# Similarity between Sentence 1 and Sentence 88: 0.7915068864822388
# Similarity between Sentence 1 and Sentence 89: 0.7747450470924377
# Similarity between Sentence 1 and Sentence 90: 0.7385159730911255
# Similarity between Sentence 1 and Sentence 91: 0.7001452445983887
# Similarity between Sentence 1 and Sentence 92: 0.7347091436386108
# Similarity between Sentence 1 and Sentence 93: 0.758786678314209
# Similarity between Sentence 1 and Sentence 94: 0.7395266890525818
# Similarity between Sentence 1 and Sentence 95: 0.7436262369155884
# Similarity between Sentence 1 and Sentence 96: 0.7361260056495667
# Similarity between Sentence 1 and Sentence 97: 0.7610833644866943
# Similarity between Sentence 1 and Sentence 98: 0.777001678943634
# Similarity between Sentence 1 and Sentence 99: 0.8058789372444153
# Similarity between Sentence 1 and Sentence 100: 0.7652167081832886
# Similarity between Sentence 1 and Sentence 101: 0.73516845703125
# Similarity between Sentence 1 and Sentence 102: 0.7676050066947937
# Similarity between Sentence 1 and Sentence 103: 0.7143313884735107
# Similarity between Sentence 2 and Sentence 3: 0.7827767133712769
# Similarity between Sentence 2 and Sentence 4: 0.7295656204223633
# Similarity between Sentence 2 and Sentence 5: 0.8015981912612915
# Similarity between Sentence 2 and Sentence 6: 0.905194878578186
# Similarity between Sentence 2 and Sentence 7: 0.889635443687439
# Similarity between Sentence 2 and Sentence 8: 0.8086548447608948
# Similarity between Sentence 2 and Sentence 9: 0.7939411401748657
# Similarity between Sentence 2 and Sentence 10: 0.8298304080963135
# Similarity between Sentence 2 and Sentence 11: 0.8677600026130676
# Similarity between Sentence 2 and Sentence 12: 0.8291475772857666
# Similarity between Sentence 2 and Sentence 13: 0.8240604996681213
# Similarity between Sentence 2 and Sentence 14: 0.8333278298377991
# Similarity between Sentence 2 and Sentence 15: 0.7589584589004517
# Similarity between Sentence 2 and Sentence 16: 0.8372498750686646
# Similarity between Sentence 2 and Sentence 17: 0.853034257888794
# Similarity between Sentence 2 and Sentence 18: 0.819473385810852
# Similarity between Sentence 2 and Sentence 19: 0.8076848983764648
# Similarity between Sentence 2 and Sentence 20: 0.7945104837417603
# Similarity between Sentence 2 and Sentence 21: 0.8137351274490356
# Similarity between Sentence 2 and Sentence 22: 0.8262879848480225
# Similarity between Sentence 2 and Sentence 23: 0.8335872292518616
# Similarity between Sentence 2 and Sentence 24: 0.8260465860366821
# Similarity between Sentence 2 and Sentence 25: 0.8498470783233643
# Similarity between Sentence 2 and Sentence 26: 0.8319627046585083
# Similarity between Sentence 2 and Sentence 27: 0.8527270555496216
# Similarity between Sentence 2 and Sentence 28: 0.8155660033226013
# Similarity between Sentence 2 and Sentence 29: 0.7878690958023071
# Similarity between Sentence 2 and Sentence 30: 0.8085988759994507
# Similarity between Sentence 2 and Sentence 31: 0.7737340927124023
# Similarity between Sentence 2 and Sentence 32: 0.8158479928970337
# Similarity between Sentence 2 and Sentence 33: 0.8055757880210876
# Similarity between Sentence 2 and Sentence 34: 0.8530003428459167
# Similarity between Sentence 2 and Sentence 35: 0.8032354116439819
# Similarity between Sentence 2 and Sentence 36: 0.8759812712669373
# Similarity between Sentence 2 and Sentence 37: 0.8678463101387024
# Similarity between Sentence 2 and Sentence 38: 0.9019484519958496
# Similarity between Sentence 2 and Sentence 39: 0.7257603406906128
# Similarity between Sentence 2 and Sentence 40: 0.8474592566490173
# Similarity between Sentence 2 and Sentence 41: 0.8280355334281921
# Similarity between Sentence 2 and Sentence 42: 0.8378521800041199
# Similarity between Sentence 2 and Sentence 43: 0.8021576404571533
# Similarity between Sentence 2 and Sentence 44: 0.7618368864059448
# Similarity between Sentence 2 and Sentence 45: 0.7537237405776978
# Similarity between Sentence 2 and Sentence 46: 0.8199672698974609
# Similarity between Sentence 2 and Sentence 47: 0.836880087852478
# Similarity between Sentence 2 and Sentence 48: 0.8287152051925659
# Similarity between Sentence 2 and Sentence 49: 0.8022651672363281
# Similarity between Sentence 2 and Sentence 50: 0.8247261047363281
# Similarity between Sentence 2 and Sentence 51: 0.8519247174263
# Similarity between Sentence 2 and Sentence 52: 0.8372482657432556
# Similarity between Sentence 2 and Sentence 53: 0.8373173475265503
# Similarity between Sentence 2 and Sentence 54: 0.8137912750244141
# Similarity between Sentence 2 and Sentence 55: 0.7822916507720947
# Similarity between Sentence 2 and Sentence 56: 0.8143019676208496
# Similarity between Sentence 2 and Sentence 57: 0.7904191017150879
# Similarity between Sentence 2 and Sentence 58: 0.7895855903625488
# Similarity between Sentence 2 and Sentence 59: 0.7917080521583557
# Similarity between Sentence 2 and Sentence 60: 0.7771062254905701
# Similarity between Sentence 2 and Sentence 61: 0.8260830044746399
# Similarity between Sentence 2 and Sentence 62: 0.7544118165969849
# Similarity between Sentence 2 and Sentence 63: 0.762770414352417
# Similarity between Sentence 2 and Sentence 64: 0.8224570155143738
# Similarity between Sentence 2 and Sentence 65: 0.8310118913650513
# Similarity between Sentence 2 and Sentence 66: 0.7801952362060547
# Similarity between Sentence 2 and Sentence 67: 0.8052821159362793
# Similarity between Sentence 2 and Sentence 68: 0.7941073179244995
# Similarity between Sentence 2 and Sentence 69: 0.8034748435020447
# Similarity between Sentence 2 and Sentence 70: 0.7992727756500244
# Similarity between Sentence 2 and Sentence 71: 0.7868465185165405
# Similarity between Sentence 2 and Sentence 72: 0.7571747899055481
# Similarity between Sentence 2 and Sentence 73: 0.8210833668708801
# Similarity between Sentence 2 and Sentence 74: 0.8036460280418396
# Similarity between Sentence 2 and Sentence 75: 0.7852667570114136
# Similarity between Sentence 2 and Sentence 76: 0.7782397270202637
# Similarity between Sentence 2 and Sentence 77: 0.755439043045044
# Similarity between Sentence 2 and Sentence 78: 0.7715107798576355
# Similarity between Sentence 2 and Sentence 79: 0.7239067554473877
# Similarity between Sentence 2 and Sentence 80: 0.7757712602615356
# Similarity between Sentence 2 and Sentence 81: 0.8129231929779053
# Similarity between Sentence 2 and Sentence 82: 0.7729508280754089
# Similarity between Sentence 2 and Sentence 83: 0.6978962421417236
# Similarity between Sentence 2 and Sentence 84: 0.7268768548965454
# Similarity between Sentence 2 and Sentence 85: 0.8860775232315063
# Similarity between Sentence 2 and Sentence 86: 0.8013901710510254
# Similarity between Sentence 2 and Sentence 87: 0.8447775840759277
# Similarity between Sentence 2 and Sentence 88: 0.7749477624893188
# Similarity between Sentence 2 and Sentence 89: 0.8402129411697388
# Similarity between Sentence 2 and Sentence 90: 0.7908989191055298
# Similarity between Sentence 2 and Sentence 91: 0.7674708962440491
# Similarity between Sentence 2 and Sentence 92: 0.8340228796005249
# Similarity between Sentence 2 and Sentence 93: 0.732107400894165
# Similarity between Sentence 2 and Sentence 94: 0.7393524646759033
# Similarity between Sentence 2 and Sentence 95: 0.7105525732040405
# Similarity between Sentence 2 and Sentence 96: 0.7916227579116821
# Similarity between Sentence 2 and Sentence 97: 0.8179877996444702
# Similarity between Sentence 2 and Sentence 98: 0.8685394525527954
# Similarity between Sentence 2 and Sentence 99: 0.8318156003952026
# Similarity between Sentence 2 and Sentence 100: 0.7889298796653748
# Similarity between Sentence 2 and Sentence 101: 0.7474721670150757
# Similarity between Sentence 2 and Sentence 102: 0.7877616882324219
# Similarity between Sentence 2 and Sentence 103: 0.7634836435317993
# Similarity between Sentence 3 and Sentence 4: 0.7994345426559448
# Similarity between Sentence 3 and Sentence 5: 0.8021774291992188
# Similarity between Sentence 3 and Sentence 6: 0.8391032814979553
# Similarity between Sentence 3 and Sentence 7: 0.7871547937393188
# Similarity between Sentence 3 and Sentence 8: 0.8738237619400024
# Similarity between Sentence 3 and Sentence 9: 0.8388310074806213
# Similarity between Sentence 3 and Sentence 10: 0.8477554321289062
# Similarity between Sentence 3 and Sentence 11: 0.8618799448013306
# Similarity between Sentence 3 and Sentence 12: 0.8805079460144043
# Similarity between Sentence 3 and Sentence 13: 0.8836081624031067
# Similarity between Sentence 3 and Sentence 14: 0.852292537689209
# Similarity between Sentence 3 and Sentence 15: 0.7493582963943481
# Similarity between Sentence 3 and Sentence 16: 0.7694920301437378
# Similarity between Sentence 3 and Sentence 17: 0.8251131176948547
# Similarity between Sentence 3 and Sentence 18: 0.8419777154922485
# Similarity between Sentence 3 and Sentence 19: 0.8749968409538269
# Similarity between Sentence 3 and Sentence 20: 0.8070353865623474
# Similarity between Sentence 3 and Sentence 21: 0.88493812084198
# Similarity between Sentence 3 and Sentence 22: 0.8234905004501343
# Similarity between Sentence 3 and Sentence 23: 0.8819788098335266
# Similarity between Sentence 3 and Sentence 24: 0.8437042236328125
# Similarity between Sentence 3 and Sentence 25: 0.8687848448753357
# Similarity between Sentence 3 and Sentence 26: 0.82545006275177
# Similarity between Sentence 3 and Sentence 27: 0.8828415274620056
# Similarity between Sentence 3 and Sentence 28: 0.8662368059158325
# Similarity between Sentence 3 and Sentence 29: 0.8386070728302002
# Similarity between Sentence 3 and Sentence 30: 0.8710907697677612
# Similarity between Sentence 3 and Sentence 31: 0.9054281711578369
# Similarity between Sentence 3 and Sentence 32: 0.8621432781219482
# Similarity between Sentence 3 and Sentence 33: 0.8465009927749634
# Similarity between Sentence 3 and Sentence 34: 0.837721586227417
# Similarity between Sentence 3 and Sentence 35: 0.7907149791717529
# Similarity between Sentence 3 and Sentence 36: 0.8093447089195251
# Similarity between Sentence 3 and Sentence 37: 0.8327006697654724
# Similarity between Sentence 3 and Sentence 38: 0.8576700687408447
# Similarity between Sentence 3 and Sentence 39: 0.8683562278747559
# Similarity between Sentence 3 and Sentence 40: 0.8496489524841309
# Similarity between Sentence 3 and Sentence 41: 0.9148847460746765
# Similarity between Sentence 3 and Sentence 42: 0.8223776817321777
# Similarity between Sentence 3 and Sentence 43: 0.8904872536659241
# Similarity between Sentence 3 and Sentence 44: 0.9116735458374023
# Similarity between Sentence 3 and Sentence 45: 0.9066771268844604
# Similarity between Sentence 3 and Sentence 46: 0.8871318101882935
# Similarity between Sentence 3 and Sentence 47: 0.8918792009353638
# Similarity between Sentence 3 and Sentence 48: 0.8918061256408691
# Similarity between Sentence 3 and Sentence 49: 0.9041579961776733
# Similarity between Sentence 3 and Sentence 50: 0.8501490354537964
# Similarity between Sentence 3 and Sentence 51: 0.8429449796676636
# Similarity between Sentence 3 and Sentence 52: 0.894119918346405
# Similarity between Sentence 3 and Sentence 53: 0.8784017562866211
# Similarity between Sentence 3 and Sentence 54: 0.8997762203216553
# Similarity between Sentence 3 and Sentence 55: 0.8441895246505737
# Similarity between Sentence 3 and Sentence 56: 0.7261967062950134
# Similarity between Sentence 3 and Sentence 57: 0.9037096500396729
# Similarity between Sentence 3 and Sentence 58: 0.8639916777610779
# Similarity between Sentence 3 and Sentence 59: 0.8264256715774536
# Similarity between Sentence 3 and Sentence 60: 0.9018144011497498
# Similarity between Sentence 3 and Sentence 61: 0.8334273099899292
# Similarity between Sentence 3 and Sentence 62: 0.8737767338752747
# Similarity between Sentence 3 and Sentence 63: 0.7065269351005554
# Similarity between Sentence 3 and Sentence 64: 0.8250988125801086
# Similarity between Sentence 3 and Sentence 65: 0.8533358573913574
# Similarity between Sentence 3 and Sentence 66: 0.8606806397438049
# Similarity between Sentence 3 and Sentence 67: 0.7919482588768005
# Similarity between Sentence 3 and Sentence 68: 0.8222687244415283
# Similarity between Sentence 3 and Sentence 69: 0.8242011666297913
# Similarity between Sentence 3 and Sentence 70: 0.8479723930358887
# Similarity between Sentence 3 and Sentence 71: 0.8834827542304993
# Similarity between Sentence 3 and Sentence 72: 0.6574066281318665
# Similarity between Sentence 3 and Sentence 73: 0.775615930557251
# Similarity between Sentence 3 and Sentence 74: 0.8752412796020508
# Similarity between Sentence 3 and Sentence 75: 0.8353617191314697
# Similarity between Sentence 3 and Sentence 76: 0.8738555908203125
# Similarity between Sentence 3 and Sentence 77: 0.8556740283966064
# Similarity between Sentence 3 and Sentence 78: 0.7920966148376465
# Similarity between Sentence 3 and Sentence 79: 0.8326997756958008
# Similarity between Sentence 3 and Sentence 80: 0.8161499500274658
# Similarity between Sentence 3 and Sentence 81: 0.8053747415542603
# Similarity between Sentence 3 and Sentence 82: 0.848578929901123
# Similarity between Sentence 3 and Sentence 83: 0.7467219829559326
# Similarity between Sentence 3 and Sentence 84: 0.7437485456466675
# Similarity between Sentence 3 and Sentence 85: 0.8133044838905334
# Similarity between Sentence 3 and Sentence 86: 0.8596821427345276
# Similarity between Sentence 3 and Sentence 87: 0.7974509000778198
# Similarity between Sentence 3 and Sentence 88: 0.9005702137947083
# Similarity between Sentence 3 and Sentence 89: 0.8478289842605591
# Similarity between Sentence 3 and Sentence 90: 0.8509987592697144
# Similarity between Sentence 3 and Sentence 91: 0.8538839817047119
# Similarity between Sentence 3 and Sentence 92: 0.8412846326828003
# Similarity between Sentence 3 and Sentence 93: 0.8496667146682739
# Similarity between Sentence 3 and Sentence 94: 0.8607228994369507
# Similarity between Sentence 3 and Sentence 95: 0.8289715051651001
# Similarity between Sentence 3 and Sentence 96: 0.8453159928321838
# Similarity between Sentence 3 and Sentence 97: 0.9051508903503418
# Similarity between Sentence 3 and Sentence 98: 0.8219537138938904
# Similarity between Sentence 3 and Sentence 99: 0.8213223218917847
# Similarity between Sentence 3 and Sentence 100: 0.9054892063140869
# Similarity between Sentence 3 and Sentence 101: 0.6654428839683533
# Similarity between Sentence 3 and Sentence 102: 0.8150643110275269
# Similarity between Sentence 3 and Sentence 103: 0.8316254615783691
# Similarity between Sentence 4 and Sentence 5: 0.7722786664962769
# Similarity between Sentence 4 and Sentence 6: 0.8018766641616821
# Similarity between Sentence 4 and Sentence 7: 0.759464681148529
# Similarity between Sentence 4 and Sentence 8: 0.7825368642807007
# Similarity between Sentence 4 and Sentence 9: 0.7207086086273193
# Similarity between Sentence 4 and Sentence 10: 0.736385703086853
# Similarity between Sentence 4 and Sentence 11: 0.7144529819488525
# Similarity between Sentence 4 and Sentence 12: 0.7627825140953064
# Similarity between Sentence 4 and Sentence 13: 0.7466989755630493
# Similarity between Sentence 4 and Sentence 14: 0.7564164400100708
# Similarity between Sentence 4 and Sentence 15: 0.6290457248687744
# Similarity between Sentence 4 and Sentence 16: 0.6019836664199829
# Similarity between Sentence 4 and Sentence 17: 0.6246195435523987
# Similarity between Sentence 4 and Sentence 18: 0.7788360714912415
# Similarity between Sentence 4 and Sentence 19: 0.7441333532333374
# Similarity between Sentence 4 and Sentence 20: 0.6460469961166382
# Similarity between Sentence 4 and Sentence 21: 0.7709959149360657
# Similarity between Sentence 4 and Sentence 22: 0.6445373296737671
# Similarity between Sentence 4 and Sentence 23: 0.7415543794631958
# Similarity between Sentence 4 and Sentence 24: 0.8235968947410583
# Similarity between Sentence 4 and Sentence 25: 0.8175822496414185
# Similarity between Sentence 4 and Sentence 26: 0.6641637682914734
# Similarity between Sentence 4 and Sentence 27: 0.7346571683883667
# Similarity between Sentence 4 and Sentence 28: 0.7093260288238525
# Similarity between Sentence 4 and Sentence 29: 0.800180196762085
# Similarity between Sentence 4 and Sentence 30: 0.770707905292511
# Similarity between Sentence 4 and Sentence 31: 0.8413517475128174
# Similarity between Sentence 4 and Sentence 32: 0.7694448232650757
# Similarity between Sentence 4 and Sentence 33: 0.6653512120246887
# Similarity between Sentence 4 and Sentence 34: 0.6651401519775391
# Similarity between Sentence 4 and Sentence 35: 0.6149006485939026
# Similarity between Sentence 4 and Sentence 36: 0.8095279932022095
# Similarity between Sentence 4 and Sentence 37: 0.7814183235168457
# Similarity between Sentence 4 and Sentence 38: 0.7800565958023071
# Similarity between Sentence 4 and Sentence 39: 0.8022949695587158
# Similarity between Sentence 4 and Sentence 40: 0.7133586406707764
# Similarity between Sentence 4 and Sentence 41: 0.8341967463493347
# Similarity between Sentence 4 and Sentence 42: 0.8424581289291382
# Similarity between Sentence 4 and Sentence 43: 0.8205510377883911
# Similarity between Sentence 4 and Sentence 44: 0.8745682239532471
# Similarity between Sentence 4 and Sentence 45: 0.838553786277771
# Similarity between Sentence 4 and Sentence 46: 0.845772385597229
# Similarity between Sentence 4 and Sentence 47: 0.7299571633338928
# Similarity between Sentence 4 and Sentence 48: 0.7812798023223877
# Similarity between Sentence 4 and Sentence 49: 0.8200246095657349
# Similarity between Sentence 4 and Sentence 50: 0.8534874320030212
# Similarity between Sentence 4 and Sentence 51: 0.6823431253433228
# Similarity between Sentence 4 and Sentence 52: 0.7248858213424683
# Similarity between Sentence 4 and Sentence 53: 0.7512439489364624
# Similarity between Sentence 4 and Sentence 54: 0.8168855309486389
# Similarity between Sentence 4 and Sentence 55: 0.836965799331665
# Similarity between Sentence 4 and Sentence 56: 0.7718378305435181
# Similarity between Sentence 4 and Sentence 57: 0.8064336776733398
# Similarity between Sentence 4 and Sentence 58: 0.7055761218070984
# Similarity between Sentence 4 and Sentence 59: 0.6298968195915222
# Similarity between Sentence 4 and Sentence 60: 0.7329701781272888
# Similarity between Sentence 4 and Sentence 61: 0.7684056758880615
# Similarity between Sentence 4 and Sentence 62: 0.7658100128173828
# Similarity between Sentence 4 and Sentence 63: 0.6236969232559204
# Similarity between Sentence 4 and Sentence 64: 0.6922812461853027
# Similarity between Sentence 4 and Sentence 65: 0.8199140429496765
# Similarity between Sentence 4 and Sentence 66: 0.7235202789306641
# Similarity between Sentence 4 and Sentence 67: 0.5920547246932983
# Similarity between Sentence 4 and Sentence 68: 0.6440774202346802
# Similarity between Sentence 4 and Sentence 69: 0.8130253553390503
# Similarity between Sentence 4 and Sentence 70: 0.6723603010177612
# Similarity between Sentence 4 and Sentence 71: 0.6888483762741089
# Similarity between Sentence 4 and Sentence 72: 0.6669642329216003
# Similarity between Sentence 4 and Sentence 73: 0.8215973973274231
# Similarity between Sentence 4 and Sentence 74: 0.6982485055923462
# Similarity between Sentence 4 and Sentence 75: 0.7041283845901489
# Similarity between Sentence 4 and Sentence 76: 0.9005723595619202
# Similarity between Sentence 4 and Sentence 77: 0.7364614009857178
# Similarity between Sentence 4 and Sentence 78: 0.7414899468421936
# Similarity between Sentence 4 and Sentence 79: 0.9003507494926453
# Similarity between Sentence 4 and Sentence 80: 0.857331395149231
# Similarity between Sentence 4 and Sentence 81: 0.7174415588378906
# Similarity between Sentence 4 and Sentence 82: 0.8312885165214539
# Similarity between Sentence 4 and Sentence 83: 0.7373731732368469
# Similarity between Sentence 4 and Sentence 84: 0.7236182689666748
# Similarity between Sentence 4 and Sentence 85: 0.7998225688934326
# Similarity between Sentence 4 and Sentence 86: 0.7897888422012329
# Similarity between Sentence 4 and Sentence 87: 0.7510721683502197
# Similarity between Sentence 4 and Sentence 88: 0.7456822395324707
# Similarity between Sentence 4 and Sentence 89: 0.7111859321594238
# Similarity between Sentence 4 and Sentence 90: 0.6433978080749512
# Similarity between Sentence 4 and Sentence 91: 0.8146420121192932
# Similarity between Sentence 4 and Sentence 92: 0.7967277765274048
# Similarity between Sentence 4 and Sentence 93: 0.907200276851654
# Similarity between Sentence 4 and Sentence 94: 0.8781133890151978
# Similarity between Sentence 4 and Sentence 95: 0.766703188419342
# Similarity between Sentence 4 and Sentence 96: 0.6588549017906189
# Similarity between Sentence 4 and Sentence 97: 0.8137605786323547
# Similarity between Sentence 4 and Sentence 98: 0.7604057788848877
# Similarity between Sentence 4 and Sentence 99: 0.8084275126457214
# Similarity between Sentence 4 and Sentence 100: 0.7986564636230469
# Similarity between Sentence 4 and Sentence 101: 0.6787508130073547
# Similarity between Sentence 4 and Sentence 102: 0.7349172830581665
# Similarity between Sentence 4 and Sentence 103: 0.648329496383667
# Similarity between Sentence 5 and Sentence 6: 0.8090357184410095
# Similarity between Sentence 5 and Sentence 7: 0.8281660676002502
# Similarity between Sentence 5 and Sentence 8: 0.8134256601333618
# Similarity between Sentence 5 and Sentence 9: 0.8026313781738281
# Similarity between Sentence 5 and Sentence 10: 0.825882613658905
# Similarity between Sentence 5 and Sentence 11: 0.8438576459884644
# Similarity between Sentence 5 and Sentence 12: 0.8402529954910278
# Similarity between Sentence 5 and Sentence 13: 0.8448549509048462
# Similarity between Sentence 5 and Sentence 14: 0.8192218542098999
# Similarity between Sentence 5 and Sentence 15: 0.7733573317527771
# Similarity between Sentence 5 and Sentence 16: 0.769811749458313
# Similarity between Sentence 5 and Sentence 17: 0.7632871866226196
# Similarity between Sentence 5 and Sentence 18: 0.8418135046958923
# Similarity between Sentence 5 and Sentence 19: 0.801352322101593
# Similarity between Sentence 5 and Sentence 20: 0.7574537992477417
# Similarity between Sentence 5 and Sentence 21: 0.8210666179656982
# Similarity between Sentence 5 and Sentence 22: 0.7886726260185242
# Similarity between Sentence 5 and Sentence 23: 0.8347973227500916
# Similarity between Sentence 5 and Sentence 24: 0.7458277344703674
# Similarity between Sentence 5 and Sentence 25: 0.7731842994689941
# Similarity between Sentence 5 and Sentence 26: 0.785848081111908
# Similarity between Sentence 5 and Sentence 27: 0.798596978187561
# Similarity between Sentence 5 and Sentence 28: 0.8279649019241333
# Similarity between Sentence 5 and Sentence 29: 0.7897727489471436
# Similarity between Sentence 5 and Sentence 30: 0.8254610300064087
# Similarity between Sentence 5 and Sentence 31: 0.8235830664634705
# Similarity between Sentence 5 and Sentence 32: 0.8293305039405823
# Similarity between Sentence 5 and Sentence 33: 0.7586200833320618
# Similarity between Sentence 5 and Sentence 34: 0.7904259562492371
# Similarity between Sentence 5 and Sentence 35: 0.7642026543617249
# Similarity between Sentence 5 and Sentence 36: 0.7840921878814697
# Similarity between Sentence 5 and Sentence 37: 0.8319640159606934
# Similarity between Sentence 5 and Sentence 38: 0.8132086992263794
# Similarity between Sentence 5 and Sentence 39: 0.7387630939483643
# Similarity between Sentence 5 and Sentence 40: 0.8212999105453491
# Similarity between Sentence 5 and Sentence 41: 0.8395353555679321
# Similarity between Sentence 5 and Sentence 42: 0.8049887418746948
# Similarity between Sentence 5 and Sentence 43: 0.8420393466949463
# Similarity between Sentence 5 and Sentence 44: 0.8282256126403809
# Similarity between Sentence 5 and Sentence 45: 0.7930436134338379
# Similarity between Sentence 5 and Sentence 46: 0.8469600677490234
# Similarity between Sentence 5 and Sentence 47: 0.8466575145721436
# Similarity between Sentence 5 and Sentence 48: 0.846253514289856
# Similarity between Sentence 5 and Sentence 49: 0.8520466685295105
# Similarity between Sentence 5 and Sentence 50: 0.7885488271713257
# Similarity between Sentence 5 and Sentence 51: 0.8387501239776611
# Similarity between Sentence 5 and Sentence 52: 0.846284806728363
# Similarity between Sentence 5 and Sentence 53: 0.8271939754486084
# Similarity between Sentence 5 and Sentence 54: 0.8060210943222046
# Similarity between Sentence 5 and Sentence 55: 0.9048548936843872
# Similarity between Sentence 5 and Sentence 56: 0.7582038640975952
# Similarity between Sentence 5 and Sentence 57: 0.8123801946640015
# Similarity between Sentence 5 and Sentence 58: 0.7901124358177185
# Similarity between Sentence 5 and Sentence 59: 0.7985124588012695
# Similarity between Sentence 5 and Sentence 60: 0.7932881712913513
# Similarity between Sentence 5 and Sentence 61: 0.8363471031188965
# Similarity between Sentence 5 and Sentence 62: 0.8140846490859985
# Similarity between Sentence 5 and Sentence 63: 0.8558831214904785
# Similarity between Sentence 5 and Sentence 64: 0.8394102454185486
# Similarity between Sentence 5 and Sentence 65: 0.8069174289703369
# Similarity between Sentence 5 and Sentence 66: 0.8125607371330261
# Similarity between Sentence 5 and Sentence 67: 0.7734783291816711
# Similarity between Sentence 5 and Sentence 68: 0.7931936383247375
# Similarity between Sentence 5 and Sentence 69: 0.8006511926651001
# Similarity between Sentence 5 and Sentence 70: 0.8276862502098083
# Similarity between Sentence 5 and Sentence 71: 0.8279099464416504
# Similarity between Sentence 5 and Sentence 72: 0.7730401754379272
# Similarity between Sentence 5 and Sentence 73: 0.8011751174926758
# Similarity between Sentence 5 and Sentence 74: 0.8375622034072876
# Similarity between Sentence 5 and Sentence 75: 0.838537335395813
# Similarity between Sentence 5 and Sentence 76: 0.8152058720588684
# Similarity between Sentence 5 and Sentence 77: 0.8063049912452698
# Similarity between Sentence 5 and Sentence 78: 0.8320270776748657
# Similarity between Sentence 5 and Sentence 79: 0.7878568172454834
# Similarity between Sentence 5 and Sentence 80: 0.7854701280593872
# Similarity between Sentence 5 and Sentence 81: 0.8163037896156311
# Similarity between Sentence 5 and Sentence 82: 0.8420587778091431
# Similarity between Sentence 5 and Sentence 83: 0.8314104080200195
# Similarity between Sentence 5 and Sentence 84: 0.8332143425941467
# Similarity between Sentence 5 and Sentence 85: 0.76642906665802
# Similarity between Sentence 5 and Sentence 86: 0.8227491974830627
# Similarity between Sentence 5 and Sentence 87: 0.8098638653755188
# Similarity between Sentence 5 and Sentence 88: 0.8372188806533813
# Similarity between Sentence 5 and Sentence 89: 0.8239538669586182
# Similarity between Sentence 5 and Sentence 90: 0.7941184043884277
# Similarity between Sentence 5 and Sentence 91: 0.7425119280815125
# Similarity between Sentence 5 and Sentence 92: 0.8117470145225525
# Similarity between Sentence 5 and Sentence 93: 0.8032506704330444
# Similarity between Sentence 5 and Sentence 94: 0.8234506845474243
# Similarity between Sentence 5 and Sentence 95: 0.7727961540222168
# Similarity between Sentence 5 and Sentence 96: 0.7892012000083923
# Similarity between Sentence 5 and Sentence 97: 0.858330249786377
# Similarity between Sentence 5 and Sentence 98: 0.8094815611839294
# Similarity between Sentence 5 and Sentence 99: 0.832480251789093
# Similarity between Sentence 5 and Sentence 100: 0.8592844009399414
# Similarity between Sentence 5 and Sentence 101: 0.8441740274429321
# Similarity between Sentence 5 and Sentence 102: 0.8237264156341553
# Similarity between Sentence 5 and Sentence 103: 0.7862035632133484
# Similarity between Sentence 6 and Sentence 7: 0.8859553933143616
# Similarity between Sentence 6 and Sentence 8: 0.8581050038337708
# Similarity between Sentence 6 and Sentence 9: 0.8372269868850708
# Similarity between Sentence 6 and Sentence 10: 0.8589065074920654
# Similarity between Sentence 6 and Sentence 11: 0.8659512400627136
# Similarity between Sentence 6 and Sentence 12: 0.8324116468429565
# Similarity between Sentence 6 and Sentence 13: 0.8247692584991455
# Similarity between Sentence 6 and Sentence 14: 0.8289284110069275
# Similarity between Sentence 6 and Sentence 15: 0.7502208948135376
# Similarity between Sentence 6 and Sentence 16: 0.8033820986747742
# Similarity between Sentence 6 and Sentence 17: 0.8173575401306152
# Similarity between Sentence 6 and Sentence 18: 0.8183123469352722
# Similarity between Sentence 6 and Sentence 19: 0.8059158325195312
# Similarity between Sentence 6 and Sentence 20: 0.7485700845718384
# Similarity between Sentence 6 and Sentence 21: 0.847232460975647
# Similarity between Sentence 6 and Sentence 22: 0.815187394618988
# Similarity between Sentence 6 and Sentence 23: 0.8334139585494995
# Similarity between Sentence 6 and Sentence 24: 0.8715356588363647
# Similarity between Sentence 6 and Sentence 25: 0.8868793249130249
# Similarity between Sentence 6 and Sentence 26: 0.8135694265365601
# Similarity between Sentence 6 and Sentence 27: 0.8479306101799011
# Similarity between Sentence 6 and Sentence 28: 0.8169115781784058
# Similarity between Sentence 6 and Sentence 29: 0.7896833419799805
# Similarity between Sentence 6 and Sentence 30: 0.8394809365272522
# Similarity between Sentence 6 and Sentence 31: 0.8401134014129639
# Similarity between Sentence 6 and Sentence 32: 0.8381878137588501
# Similarity between Sentence 6 and Sentence 33: 0.7874784469604492
# Similarity between Sentence 6 and Sentence 34: 0.8255943655967712
# Similarity between Sentence 6 and Sentence 35: 0.7804476022720337
# Similarity between Sentence 6 and Sentence 36: 0.9093633890151978
# Similarity between Sentence 6 and Sentence 37: 0.8903615474700928
# Similarity between Sentence 6 and Sentence 38: 0.9344034790992737
# Similarity between Sentence 6 and Sentence 39: 0.8127626180648804
# Similarity between Sentence 6 and Sentence 40: 0.8188945055007935
# Similarity between Sentence 6 and Sentence 41: 0.8705867528915405
# Similarity between Sentence 6 and Sentence 42: 0.8939670920372009
# Similarity between Sentence 6 and Sentence 43: 0.8429203033447266
# Similarity between Sentence 6 and Sentence 44: 0.838679313659668
# Similarity between Sentence 6 and Sentence 45: 0.8405522704124451
# Similarity between Sentence 6 and Sentence 46: 0.8673325777053833
# Similarity between Sentence 6 and Sentence 47: 0.8676275610923767
# Similarity between Sentence 6 and Sentence 48: 0.8482906818389893
# Similarity between Sentence 6 and Sentence 49: 0.85554039478302
# Similarity between Sentence 6 and Sentence 50: 0.8779650926589966
# Similarity between Sentence 6 and Sentence 51: 0.8391512632369995
# Similarity between Sentence 6 and Sentence 52: 0.8588191270828247
# Similarity between Sentence 6 and Sentence 53: 0.8415381908416748
# Similarity between Sentence 6 and Sentence 54: 0.8429185152053833
# Similarity between Sentence 6 and Sentence 55: 0.8310949206352234
# Similarity between Sentence 6 and Sentence 56: 0.8361026644706726
# Similarity between Sentence 6 and Sentence 57: 0.8363879919052124
# Similarity between Sentence 6 and Sentence 58: 0.7833357453346252
# Similarity between Sentence 6 and Sentence 59: 0.800865650177002
# Similarity between Sentence 6 and Sentence 60: 0.8399931192398071
# Similarity between Sentence 6 and Sentence 61: 0.8512390851974487
# Similarity between Sentence 6 and Sentence 62: 0.7703953385353088
# Similarity between Sentence 6 and Sentence 63: 0.7364460825920105
# Similarity between Sentence 6 and Sentence 64: 0.7986789345741272
# Similarity between Sentence 6 and Sentence 65: 0.8903363943099976
# Similarity between Sentence 6 and Sentence 66: 0.805975079536438
# Similarity between Sentence 6 and Sentence 67: 0.7902974486351013
# Similarity between Sentence 6 and Sentence 68: 0.7901962995529175
# Similarity between Sentence 6 and Sentence 69: 0.862869918346405
# Similarity between Sentence 6 and Sentence 70: 0.8029590845108032
# Similarity between Sentence 6 and Sentence 71: 0.8177758455276489
# Similarity between Sentence 6 and Sentence 72: 0.7565441727638245
# Similarity between Sentence 6 and Sentence 73: 0.8144270181655884
# Similarity between Sentence 6 and Sentence 74: 0.8158584237098694
# Similarity between Sentence 6 and Sentence 75: 0.7795378565788269
# Similarity between Sentence 6 and Sentence 76: 0.8446792364120483
# Similarity between Sentence 6 and Sentence 77: 0.7578487992286682
# Similarity between Sentence 6 and Sentence 78: 0.7847011089324951
# Similarity between Sentence 6 and Sentence 79: 0.7987251281738281
# Similarity between Sentence 6 and Sentence 80: 0.8250263929367065
# Similarity between Sentence 6 and Sentence 81: 0.8342194557189941
# Similarity between Sentence 6 and Sentence 82: 0.7887002229690552
# Similarity between Sentence 6 and Sentence 83: 0.727259635925293
# Similarity between Sentence 6 and Sentence 84: 0.7477497458457947
# Similarity between Sentence 6 and Sentence 85: 0.9025326371192932
# Similarity between Sentence 6 and Sentence 86: 0.8116183876991272
# Similarity between Sentence 6 and Sentence 87: 0.8405625224113464
# Similarity between Sentence 6 and Sentence 88: 0.8151736259460449
# Similarity between Sentence 6 and Sentence 89: 0.8509016633033752
# Similarity between Sentence 6 and Sentence 90: 0.8156170845031738
# Similarity between Sentence 6 and Sentence 91: 0.8262636661529541
# Similarity between Sentence 6 and Sentence 92: 0.8647450804710388
# Similarity between Sentence 6 and Sentence 93: 0.7965875864028931
# Similarity between Sentence 6 and Sentence 94: 0.8225038051605225
# Similarity between Sentence 6 and Sentence 95: 0.788688063621521
# Similarity between Sentence 6 and Sentence 96: 0.7957576513290405
# Similarity between Sentence 6 and Sentence 97: 0.8512549996376038
# Similarity between Sentence 6 and Sentence 98: 0.9167791604995728
# Similarity between Sentence 6 and Sentence 99: 0.8874093294143677
# Similarity between Sentence 6 and Sentence 100: 0.8102973103523254
# Similarity between Sentence 6 and Sentence 101: 0.7474191188812256
# Similarity between Sentence 6 and Sentence 102: 0.8407294154167175
# Similarity between Sentence 6 and Sentence 103: 0.7379905581474304
# Similarity between Sentence 7 and Sentence 8: 0.8262959718704224
# Similarity between Sentence 7 and Sentence 9: 0.7699309587478638
# Similarity between Sentence 7 and Sentence 10: 0.8172041177749634
# Similarity between Sentence 7 and Sentence 11: 0.8567935228347778
# Similarity between Sentence 7 and Sentence 12: 0.8036149740219116
# Similarity between Sentence 7 and Sentence 13: 0.7989509105682373
# Similarity between Sentence 7 and Sentence 14: 0.8041746020317078
# Similarity between Sentence 7 and Sentence 15: 0.7532888054847717
# Similarity between Sentence 7 and Sentence 16: 0.8129760026931763
# Similarity between Sentence 7 and Sentence 17: 0.8152767419815063
# Similarity between Sentence 7 and Sentence 18: 0.798017680644989
# Similarity between Sentence 7 and Sentence 19: 0.7720306515693665
# Similarity between Sentence 7 and Sentence 20: 0.772022008895874
# Similarity between Sentence 7 and Sentence 21: 0.7883501052856445
# Similarity between Sentence 7 and Sentence 22: 0.8159160614013672
# Similarity between Sentence 7 and Sentence 23: 0.8190918564796448
# Similarity between Sentence 7 and Sentence 24: 0.8180475831031799
# Similarity between Sentence 7 and Sentence 25: 0.8433541655540466
# Similarity between Sentence 7 and Sentence 26: 0.8469069600105286
# Similarity between Sentence 7 and Sentence 27: 0.808381199836731
# Similarity between Sentence 7 and Sentence 28: 0.7957385778427124
# Similarity between Sentence 7 and Sentence 29: 0.7665929794311523
# Similarity between Sentence 7 and Sentence 30: 0.7877163290977478
# Similarity between Sentence 7 and Sentence 31: 0.7634896039962769
# Similarity between Sentence 7 and Sentence 32: 0.7949375510215759
# Similarity between Sentence 7 and Sentence 33: 0.7972205877304077
# Similarity between Sentence 7 and Sentence 34: 0.8521361351013184
# Similarity between Sentence 7 and Sentence 35: 0.7717811465263367
# Similarity between Sentence 7 and Sentence 36: 0.8968794345855713
# Similarity between Sentence 7 and Sentence 37: 0.8627011775970459
# Similarity between Sentence 7 and Sentence 38: 0.8774502277374268
# Similarity between Sentence 7 and Sentence 39: 0.7433671355247498
# Similarity between Sentence 7 and Sentence 40: 0.8025460243225098
# Similarity between Sentence 7 and Sentence 41: 0.8214486837387085
# Similarity between Sentence 7 and Sentence 42: 0.8524572849273682
# Similarity between Sentence 7 and Sentence 43: 0.7921391725540161
# Similarity between Sentence 7 and Sentence 44: 0.7902547121047974
# Similarity between Sentence 7 and Sentence 45: 0.7762935161590576
# Similarity between Sentence 7 and Sentence 46: 0.8222306966781616
# Similarity between Sentence 7 and Sentence 47: 0.8214306831359863
# Similarity between Sentence 7 and Sentence 48: 0.8043428659439087
# Similarity between Sentence 7 and Sentence 49: 0.7955072522163391
# Similarity between Sentence 7 and Sentence 50: 0.848875105381012
# Similarity between Sentence 7 and Sentence 51: 0.8455400466918945
# Similarity between Sentence 7 and Sentence 52: 0.8295804262161255
# Similarity between Sentence 7 and Sentence 53: 0.8100264668464661
# Similarity between Sentence 7 and Sentence 54: 0.8093191385269165
# Similarity between Sentence 7 and Sentence 55: 0.8148199319839478
# Similarity between Sentence 7 and Sentence 56: 0.8152940273284912
# Similarity between Sentence 7 and Sentence 57: 0.8215020298957825
# Similarity between Sentence 7 and Sentence 58: 0.7732644081115723
# Similarity between Sentence 7 and Sentence 59: 0.7941824197769165
# Similarity between Sentence 7 and Sentence 60: 0.7742667198181152
# Similarity between Sentence 7 and Sentence 61: 0.824123203754425
# Similarity between Sentence 7 and Sentence 62: 0.7420797348022461
# Similarity between Sentence 7 and Sentence 63: 0.790522575378418
# Similarity between Sentence 7 and Sentence 64: 0.8197042942047119
# Similarity between Sentence 7 and Sentence 65: 0.838250458240509
# Similarity between Sentence 7 and Sentence 66: 0.7796809673309326
# Similarity between Sentence 7 and Sentence 67: 0.7901390790939331
# Similarity between Sentence 7 and Sentence 68: 0.7823677659034729
# Similarity between Sentence 7 and Sentence 69: 0.8068621158599854
# Similarity between Sentence 7 and Sentence 70: 0.7917300462722778
# Similarity between Sentence 7 and Sentence 71: 0.7900142669677734
# Similarity between Sentence 7 and Sentence 72: 0.7964921593666077
# Similarity between Sentence 7 and Sentence 73: 0.8225131034851074
# Similarity between Sentence 7 and Sentence 74: 0.794532060623169
# Similarity between Sentence 7 and Sentence 75: 0.756281316280365
# Similarity between Sentence 7 and Sentence 76: 0.7872000932693481
# Similarity between Sentence 7 and Sentence 77: 0.7558358907699585
# Similarity between Sentence 7 and Sentence 78: 0.7461329698562622
# Similarity between Sentence 7 and Sentence 79: 0.7552248239517212
# Similarity between Sentence 7 and Sentence 80: 0.789902925491333
# Similarity between Sentence 7 and Sentence 81: 0.7980273365974426
# Similarity between Sentence 7 and Sentence 82: 0.775360107421875
# Similarity between Sentence 7 and Sentence 83: 0.7013707160949707
# Similarity between Sentence 7 and Sentence 84: 0.7265175580978394
# Similarity between Sentence 7 and Sentence 85: 0.8839102983474731
# Similarity between Sentence 7 and Sentence 86: 0.7846806049346924
# Similarity between Sentence 7 and Sentence 87: 0.8575959205627441
# Similarity between Sentence 7 and Sentence 88: 0.7810654640197754
# Similarity between Sentence 7 and Sentence 89: 0.8038303256034851
# Similarity between Sentence 7 and Sentence 90: 0.7649593949317932
# Similarity between Sentence 7 and Sentence 91: 0.7643731832504272
# Similarity between Sentence 7 and Sentence 92: 0.8198223114013672
# Similarity between Sentence 7 and Sentence 93: 0.7486699223518372
# Similarity between Sentence 7 and Sentence 94: 0.7700193524360657
# Similarity between Sentence 7 and Sentence 95: 0.7220444679260254
# Similarity between Sentence 7 and Sentence 96: 0.7718584537506104
# Similarity between Sentence 7 and Sentence 97: 0.811234176158905
# Similarity between Sentence 7 and Sentence 98: 0.8550335168838501
# Similarity between Sentence 7 and Sentence 99: 0.8803684115409851
# Similarity between Sentence 7 and Sentence 100: 0.7741694450378418
# Similarity between Sentence 7 and Sentence 101: 0.7818412780761719
# Similarity between Sentence 7 and Sentence 102: 0.7789313793182373
# Similarity between Sentence 7 and Sentence 103: 0.729741096496582
# Similarity between Sentence 8 and Sentence 9: 0.8811178207397461
# Similarity between Sentence 8 and Sentence 10: 0.8871656656265259
# Similarity between Sentence 8 and Sentence 11: 0.87762850522995
# Similarity between Sentence 8 and Sentence 12: 0.8764176368713379
# Similarity between Sentence 8 and Sentence 13: 0.8719040155410767
# Similarity between Sentence 8 and Sentence 14: 0.8652607202529907
# Similarity between Sentence 8 and Sentence 15: 0.8702667355537415
# Similarity between Sentence 8 and Sentence 16: 0.8207142353057861
# Similarity between Sentence 8 and Sentence 17: 0.8443383574485779
# Similarity between Sentence 8 and Sentence 18: 0.842593789100647
# Similarity between Sentence 8 and Sentence 19: 0.8542044758796692
# Similarity between Sentence 8 and Sentence 20: 0.7834619283676147
# Similarity between Sentence 8 and Sentence 21: 0.8637619614601135
# Similarity between Sentence 8 and Sentence 22: 0.8497797250747681
# Similarity between Sentence 8 and Sentence 23: 0.878082275390625
# Similarity between Sentence 8 and Sentence 24: 0.8195527195930481
# Similarity between Sentence 8 and Sentence 25: 0.8460490107536316
# Similarity between Sentence 8 and Sentence 26: 0.8707060813903809
# Similarity between Sentence 8 and Sentence 27: 0.8630406856536865
# Similarity between Sentence 8 and Sentence 28: 0.8583540916442871
# Similarity between Sentence 8 and Sentence 29: 0.8249415159225464
# Similarity between Sentence 8 and Sentence 30: 0.8585408926010132
# Similarity between Sentence 8 and Sentence 31: 0.8599412441253662
# Similarity between Sentence 8 and Sentence 32: 0.8618447780609131
# Similarity between Sentence 8 and Sentence 33: 0.824859619140625
# Similarity between Sentence 8 and Sentence 34: 0.8522903323173523
# Similarity between Sentence 8 and Sentence 35: 0.8668041229248047
# Similarity between Sentence 8 and Sentence 36: 0.8185887336730957
# Similarity between Sentence 8 and Sentence 37: 0.8364046812057495
# Similarity between Sentence 8 and Sentence 38: 0.8654239177703857
# Similarity between Sentence 8 and Sentence 39: 0.8226205706596375
# Similarity between Sentence 8 and Sentence 40: 0.8617727160453796
# Similarity between Sentence 8 and Sentence 41: 0.8868849277496338
# Similarity between Sentence 8 and Sentence 42: 0.8143510818481445
# Similarity between Sentence 8 and Sentence 43: 0.8865146636962891
# ...
# Similarity between Sentence 81 and Sentence 98: 0.8340460062026978
# Similarity between Sentence 81 and Sentence 99: 0.8064724206924438
# Similarity between Sentence 81 and Sentence 100: 0.8094732761383057
# Similarity between Sentence 81 and Sentence 101: 0.7332971096038818
# Similarity between Sentence 81 and Sentence 102: 0.8821703791618347
# Similarity between Sentence 81 and Sentence 103: 0.7786064743995667
# Similarity between Sentence 82 and Sentence 83: 0.81886887550354
# Similarity between Sentence 82 and Sentence 84: 0.7862720489501953
# Similarity between Sentence 82 and Sentence 85: 0.7654383778572083
# Similarity between Sentence 82 and Sentence 86: 0.8617492318153381
# Similarity between Sentence 82 and Sentence 87: 0.8255943059921265
# Similarity between Sentence 82 and Sentence 88: 0.8420894145965576
# Similarity between Sentence 82 and Sentence 89: 0.7786692976951599
# Similarity between Sentence 82 and Sentence 90: 0.7374155521392822
# Similarity between Sentence 82 and Sentence 91: 0.7404407262802124
# Similarity between Sentence 82 and Sentence 92: 0.8282784223556519
# Similarity between Sentence 82 and Sentence 93: 0.869804322719574
# Similarity between Sentence 82 and Sentence 94: 0.8358684182167053
# Similarity between Sentence 82 and Sentence 95: 0.7744036316871643
# Similarity between Sentence 82 and Sentence 96: 0.7204490900039673
# Similarity between Sentence 82 and Sentence 97: 0.8635444641113281
# Similarity between Sentence 82 and Sentence 98: 0.7479895353317261
# Similarity between Sentence 82 and Sentence 99: 0.7581615447998047
# Similarity between Sentence 82 and Sentence 100: 0.9059035181999207
# Similarity between Sentence 82 and Sentence 101: 0.7181132435798645
# Similarity between Sentence 82 and Sentence 102: 0.7657672166824341
# Similarity between Sentence 82 and Sentence 103: 0.8087722659111023
# Similarity between Sentence 83 and Sentence 84: 0.8678915500640869
# Similarity between Sentence 83 and Sentence 85: 0.6546814441680908
# Similarity between Sentence 83 and Sentence 86: 0.7182507514953613
# Similarity between Sentence 83 and Sentence 87: 0.7189280986785889
# Similarity between Sentence 83 and Sentence 88: 0.772551417350769
# Similarity between Sentence 83 and Sentence 89: 0.7711259722709656
# Similarity between Sentence 83 and Sentence 90: 0.712165892124176
# Similarity between Sentence 83 and Sentence 91: 0.6748292446136475
# Similarity between Sentence 83 and Sentence 92: 0.7343941926956177
# Similarity between Sentence 83 and Sentence 93: 0.8245009779930115
# Similarity between Sentence 83 and Sentence 94: 0.8534196615219116
# Similarity between Sentence 83 and Sentence 95: 0.779934287071228
# Similarity between Sentence 83 and Sentence 96: 0.7081083059310913
# Similarity between Sentence 83 and Sentence 97: 0.8048605918884277
# Similarity between Sentence 83 and Sentence 98: 0.7285003662109375
# Similarity between Sentence 83 and Sentence 99: 0.7182119488716125
# Similarity between Sentence 83 and Sentence 100: 0.8355324268341064
# Similarity between Sentence 83 and Sentence 101: 0.7077552080154419
# Similarity between Sentence 83 and Sentence 102: 0.7588231563568115
# Similarity between Sentence 83 and Sentence 103: 0.6899553537368774
# Similarity between Sentence 84 and Sentence 85: 0.6736586093902588
# Similarity between Sentence 84 and Sentence 86: 0.7408393025398254
# Similarity between Sentence 84 and Sentence 87: 0.710335373878479
# Similarity between Sentence 84 and Sentence 88: 0.7725867629051208
# Similarity between Sentence 84 and Sentence 89: 0.7547749280929565
# Similarity between Sentence 84 and Sentence 90: 0.7152607440948486
# Similarity between Sentence 84 and Sentence 91: 0.6450875997543335
# Similarity between Sentence 84 and Sentence 92: 0.7323874235153198
# Similarity between Sentence 84 and Sentence 93: 0.7659478187561035
# Similarity between Sentence 84 and Sentence 94: 0.7805822491645813
# Similarity between Sentence 84 and Sentence 95: 0.7666583061218262
# Similarity between Sentence 84 and Sentence 96: 0.7097277045249939
# Similarity between Sentence 84 and Sentence 97: 0.7664788961410522
# Similarity between Sentence 84 and Sentence 98: 0.7618448734283447
# Similarity between Sentence 84 and Sentence 99: 0.7450274229049683
# Similarity between Sentence 84 and Sentence 100: 0.8228734731674194
# Similarity between Sentence 84 and Sentence 101: 0.7677918076515198
# Similarity between Sentence 84 and Sentence 102: 0.7479990720748901
# Similarity between Sentence 84 and Sentence 103: 0.6943954825401306
# Similarity between Sentence 85 and Sentence 86: 0.8105145692825317
# Similarity between Sentence 85 and Sentence 87: 0.8170705437660217
# Similarity between Sentence 85 and Sentence 88: 0.7790786027908325
# Similarity between Sentence 85 and Sentence 89: 0.8142880797386169
# Similarity between Sentence 85 and Sentence 90: 0.7753704190254211
# Similarity between Sentence 85 and Sentence 91: 0.8306229114532471
# Similarity between Sentence 85 and Sentence 92: 0.8496924638748169
# Similarity between Sentence 85 and Sentence 93: 0.765627920627594
# Similarity between Sentence 85 and Sentence 94: 0.7746099829673767
# Similarity between Sentence 85 and Sentence 95: 0.7284020781517029
# Similarity between Sentence 85 and Sentence 96: 0.7671487331390381
# Similarity between Sentence 85 and Sentence 97: 0.8264690637588501
# Similarity between Sentence 85 and Sentence 98: 0.8639809489250183
# Similarity between Sentence 85 and Sentence 99: 0.8743242025375366
# Similarity between Sentence 85 and Sentence 100: 0.7712751626968384
# Similarity between Sentence 85 and Sentence 101: 0.7122408151626587
# Similarity between Sentence 85 and Sentence 102: 0.8107408881187439
# Similarity between Sentence 85 and Sentence 103: 0.7253780364990234
# Similarity between Sentence 86 and Sentence 87: 0.8391423225402832
# Similarity between Sentence 86 and Sentence 88: 0.8329941034317017
# Similarity between Sentence 86 and Sentence 89: 0.8364653587341309
# Similarity between Sentence 86 and Sentence 90: 0.8132447600364685
# Similarity between Sentence 86 and Sentence 91: 0.7549127340316772
# Similarity between Sentence 86 and Sentence 92: 0.8736710548400879
# Similarity between Sentence 86 and Sentence 93: 0.8093857765197754
# Similarity between Sentence 86 and Sentence 94: 0.8074621558189392
# Similarity between Sentence 86 and Sentence 95: 0.7761788964271545
# Similarity between Sentence 86 and Sentence 96: 0.8132760524749756
# Similarity between Sentence 86 and Sentence 97: 0.8634939789772034
# Similarity between Sentence 86 and Sentence 98: 0.790910005569458
# Similarity between Sentence 86 and Sentence 99: 0.766859233379364
# Similarity between Sentence 86 and Sentence 100: 0.8551490306854248
# Similarity between Sentence 86 and Sentence 101: 0.7390838861465454
# Similarity between Sentence 86 and Sentence 102: 0.830908477306366
# Similarity between Sentence 86 and Sentence 103: 0.8721199035644531
# Similarity between Sentence 87 and Sentence 88: 0.8299030065536499
# Similarity between Sentence 87 and Sentence 89: 0.8273069262504578
# Similarity between Sentence 87 and Sentence 90: 0.7914120554924011
# Similarity between Sentence 87 and Sentence 91: 0.709493100643158
# Similarity between Sentence 87 and Sentence 92: 0.8030452132225037
# Similarity between Sentence 87 and Sentence 93: 0.7850552201271057
# Similarity between Sentence 87 and Sentence 94: 0.783627450466156
# Similarity between Sentence 87 and Sentence 95: 0.7123333215713501
# Similarity between Sentence 87 and Sentence 96: 0.7846262454986572
# Similarity between Sentence 87 and Sentence 97: 0.821370542049408
# Similarity between Sentence 87 and Sentence 98: 0.7859806418418884
# Similarity between Sentence 87 and Sentence 99: 0.7737065553665161
# Similarity between Sentence 87 and Sentence 100: 0.8067284822463989
# Similarity between Sentence 87 and Sentence 101: 0.7624791264533997
# Similarity between Sentence 87 and Sentence 102: 0.8063457012176514
# Similarity between Sentence 87 and Sentence 103: 0.7772517204284668
# Similarity between Sentence 88 and Sentence 89: 0.8450989723205566
# Similarity between Sentence 88 and Sentence 90: 0.8801584839820862
# Similarity between Sentence 88 and Sentence 91: 0.7894219160079956
# Similarity between Sentence 88 and Sentence 92: 0.795173168182373
# Similarity between Sentence 88 and Sentence 93: 0.8224298357963562
# Similarity between Sentence 88 and Sentence 94: 0.8257720470428467
# Similarity between Sentence 88 and Sentence 95: 0.8271048069000244
# Similarity between Sentence 88 and Sentence 96: 0.8682429790496826
# Similarity between Sentence 88 and Sentence 97: 0.8937297463417053
# Similarity between Sentence 88 and Sentence 98: 0.8111074566841125
# Similarity between Sentence 88 and Sentence 99: 0.7868292331695557
# Similarity between Sentence 88 and Sentence 100: 0.8715288639068604
# Similarity between Sentence 88 and Sentence 101: 0.7228275537490845
# Similarity between Sentence 88 and Sentence 102: 0.8468584418296814
# Similarity between Sentence 88 and Sentence 103: 0.8089503049850464
# Similarity between Sentence 89 and Sentence 90: 0.9053071737289429
# Similarity between Sentence 89 and Sentence 91: 0.8150047659873962
# Similarity between Sentence 89 and Sentence 92: 0.8594746589660645
# Similarity between Sentence 89 and Sentence 93: 0.7893637418746948
# Similarity between Sentence 89 and Sentence 94: 0.8198279738426208
# Similarity between Sentence 89 and Sentence 95: 0.8066103458404541
# Similarity between Sentence 89 and Sentence 96: 0.8888641595840454
# Similarity between Sentence 89 and Sentence 97: 0.8843380808830261
# Similarity between Sentence 89 and Sentence 98: 0.8278011083602905
# Similarity between Sentence 89 and Sentence 99: 0.8133963346481323
# Similarity between Sentence 89 and Sentence 100: 0.8539794683456421
# Similarity between Sentence 89 and Sentence 101: 0.71073317527771
# Similarity between Sentence 89 and Sentence 102: 0.8694278001785278
# Similarity between Sentence 89 and Sentence 103: 0.8479048013687134
# Similarity between Sentence 90 and Sentence 91: 0.8045486211776733
# Similarity between Sentence 90 and Sentence 92: 0.8000093698501587
# Similarity between Sentence 90 and Sentence 93: 0.7368461489677429
# Similarity between Sentence 90 and Sentence 94: 0.7718296051025391
# Similarity between Sentence 90 and Sentence 95: 0.8039948344230652
# Similarity between Sentence 90 and Sentence 96: 0.9201587438583374
# Similarity between Sentence 90 and Sentence 97: 0.8729385137557983
# Similarity between Sentence 90 and Sentence 98: 0.803193211555481
# Similarity between Sentence 90 and Sentence 99: 0.7575439214706421
# Similarity between Sentence 90 and Sentence 100: 0.8178982734680176
# Similarity between Sentence 90 and Sentence 101: 0.6896858215332031
# Similarity between Sentence 90 and Sentence 102: 0.8578589558601379
# Similarity between Sentence 90 and Sentence 103: 0.843686580657959
# Similarity between Sentence 91 and Sentence 92: 0.8210330009460449
# Similarity between Sentence 91 and Sentence 93: 0.8363944292068481
# Similarity between Sentence 91 and Sentence 94: 0.8482846617698669
# Similarity between Sentence 91 and Sentence 95: 0.7449970841407776
# Similarity between Sentence 91 and Sentence 96: 0.7935787439346313
# Similarity between Sentence 91 and Sentence 97: 0.8694337606430054
# Similarity between Sentence 91 and Sentence 98: 0.8051337599754333
# Similarity between Sentence 91 and Sentence 99: 0.8118300437927246
# Similarity between Sentence 91 and Sentence 100: 0.8005845546722412
# Similarity between Sentence 91 and Sentence 101: 0.5840665102005005
# Similarity between Sentence 91 and Sentence 102: 0.767571210861206
# Similarity between Sentence 91 and Sentence 103: 0.7355300188064575
# Similarity between Sentence 92 and Sentence 93: 0.818009614944458
# Similarity between Sentence 92 and Sentence 94: 0.8351588249206543
# Similarity between Sentence 92 and Sentence 95: 0.7847632169723511
# Similarity between Sentence 92 and Sentence 96: 0.7979167699813843
# Similarity between Sentence 92 and Sentence 97: 0.8783608675003052
# Similarity between Sentence 92 and Sentence 98: 0.8324859142303467
# Similarity between Sentence 92 and Sentence 99: 0.8170514702796936
# Similarity between Sentence 92 and Sentence 100: 0.8541834354400635
# Similarity between Sentence 92 and Sentence 101: 0.7280445694923401
# Similarity between Sentence 92 and Sentence 102: 0.8450413942337036
# Similarity between Sentence 92 and Sentence 103: 0.8252975344657898
# Similarity between Sentence 93 and Sentence 94: 0.9453829526901245
# Similarity between Sentence 93 and Sentence 95: 0.810778796672821
# Similarity between Sentence 93 and Sentence 96: 0.7231787443161011
# Similarity between Sentence 93 and Sentence 97: 0.8825179934501648
# Similarity between Sentence 93 and Sentence 98: 0.7576318383216858
# Similarity between Sentence 93 and Sentence 99: 0.7921541929244995
# Similarity between Sentence 93 and Sentence 100: 0.8634570837020874
# Similarity between Sentence 93 and Sentence 101: 0.6621532440185547
# Similarity between Sentence 93 and Sentence 102: 0.7658518552780151
# Similarity between Sentence 93 and Sentence 103: 0.7122852206230164
# Similarity between Sentence 94 and Sentence 95: 0.8217306733131409
# Similarity between Sentence 94 and Sentence 96: 0.7721748948097229
# Similarity between Sentence 94 and Sentence 97: 0.9096359014511108
# Similarity between Sentence 94 and Sentence 98: 0.8040324449539185
# Similarity between Sentence 94 and Sentence 99: 0.8014145493507385
# Similarity between Sentence 94 and Sentence 100: 0.8719829320907593
# Similarity between Sentence 94 and Sentence 101: 0.6948245167732239
# Similarity between Sentence 94 and Sentence 102: 0.817036509513855
# Similarity between Sentence 94 and Sentence 103: 0.7325803637504578
# Similarity between Sentence 95 and Sentence 96: 0.8046924471855164
# Similarity between Sentence 95 and Sentence 97: 0.831322193145752
# Similarity between Sentence 95 and Sentence 98: 0.7974562048912048
# Similarity between Sentence 95 and Sentence 99: 0.7659282684326172
# Similarity between Sentence 95 and Sentence 100: 0.8116540312767029
# Similarity between Sentence 95 and Sentence 101: 0.708449125289917
# Similarity between Sentence 95 and Sentence 102: 0.808489203453064
# Similarity between Sentence 95 and Sentence 103: 0.729548454284668
# Similarity between Sentence 96 and Sentence 97: 0.8731983304023743
# Similarity between Sentence 96 and Sentence 98: 0.8256486654281616
# Similarity between Sentence 96 and Sentence 99: 0.7460014224052429
# Similarity between Sentence 96 and Sentence 100: 0.8093162775039673
# Similarity between Sentence 96 and Sentence 101: 0.6871115565299988
# Similarity between Sentence 96 and Sentence 102: 0.8539454936981201
# Similarity between Sentence 96 and Sentence 103: 0.8484238386154175
# Similarity between Sentence 97 and Sentence 98: 0.8331949710845947
# Similarity between Sentence 97 and Sentence 99: 0.8190625905990601
# Similarity between Sentence 97 and Sentence 100: 0.9148316383361816
# Similarity between Sentence 97 and Sentence 101: 0.727096438407898
# Similarity between Sentence 97 and Sentence 102: 0.8567953705787659
# Similarity between Sentence 97 and Sentence 103: 0.8521691560745239
# Similarity between Sentence 98 and Sentence 99: 0.8659825325012207
# Similarity between Sentence 98 and Sentence 100: 0.7938081622123718
# Similarity between Sentence 98 and Sentence 101: 0.7640197277069092
# Similarity between Sentence 98 and Sentence 102: 0.8530998826026917
# Similarity between Sentence 98 and Sentence 103: 0.7455543279647827
# Similarity between Sentence 99 and Sentence 100: 0.7811455726623535
# Similarity between Sentence 99 and Sentence 101: 0.7816697955131531
# Similarity between Sentence 99 and Sentence 102: 0.8106249570846558
# Similarity between Sentence 99 and Sentence 103: 0.7076408267021179
# Similarity between Sentence 100 and Sentence 101: 0.7046834230422974
# Similarity between Sentence 100 and Sentence 102: 0.8196487426757812
# Similarity between Sentence 100 and Sentence 103: 0.8534558415412903
# Similarity between Sentence 101 and Sentence 102: 0.7823535203933716
# Similarity between Sentence 101 and Sentence 103: 0.7080368995666504
# Similarity between Sentence 102 and Sentence 103: 0.8171478509902954
# None

# %% [markdown]
# ### Cluster predict KPs with Bert Embedding

# %%
from transformers import AutoTokenizer, AutoModel
from sklearn.cluster import KMeans
import torch
import numpy as np
from sklearn.metrics import pairwise_distances_argmin_min

# Load pre-trained BERT model and tokenizer
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

def clustering_with_Bert(sentences, k) -> []:

    # Tokenize and convert sentences to BERT embeddings
    encoded_input = tokenizer(sentences, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Extract the embeddings from the model output
    sentence_embeddings = model_output.last_hidden_state.mean(dim=1).numpy()

    # # Choose the number of clusters (k)
    # k = 2

    # Apply K-means clustering
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(sentence_embeddings)

    # Get cluster labels for each sentence
    labels = kmeans.labels_

    # Get the cluster centers (optional)
    cluster_centers = kmeans.cluster_centers_

    # Find representative sentences from each cluster
    representative_indices = pairwise_distances_argmin_min(cluster_centers, sentence_embeddings)[0]

    result = []
    # Print the representative sentences
    for idx in representative_indices:
        result.append(sentences[idx])
        print(sentences[idx])
    return result
    # # Print the sentences and their corresponding cluster labels
    # for sentence, label in zip(sentences, labels):
    #     print(f"Cluster {label}: {sentence}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import pandas as pd
df = pd.read_csv('./data/processed_ArgKP21.csv')
kps = list(df['kep_points'].values)
print(len(kps))
# Out:
# 62

# %%
print(len(predict_KPs))
# Out:
# 62

# %%
import ast
# Convert the string representation to a list
print(len(ast.literal_eval(kps[0])))
# Out:
# 6

# %%
import os

# Set OMP_NUM_THREADS to 1
os.environ["OMP_NUM_THREADS"] = "1"

# Verify the setting
print("OMP_NUM_THREADS:", os.environ.get("OMP_NUM_THREADS"))
# Out:
# OMP_NUM_THREADS: 1

# %%
final_kps = []
for id, item in enumerate(predict_KPs):
    # k = len(ast.literal_eval(kps[id]))
    k=5
    print("id: "+ str(id) + "  k-means: "+ str(k))
    final_kps.append(clustering_with_Bert(item, k))
# Out:
# id: 0  k-means: 5
# Assisted suicide may be exploited by people lacking mental capacity to understand its ultimate consequences, hence it should be criminalized.
# Assisted suicide is equivalent to murder and should hence be considered a criminal offence.
# Assisted suicide may be exploited by people lacking mental capacity to understand its ultimate consequences, hence it should be criminalized.
# Assisting in suicide is equivalent to committing murder and should carry criminal charges.
# Assisted suicide is a form of ending life and thus should be considered unlawful.
# id: 1  k-means: 5
# Assisted suicide must not be a criminal offense as it provides relief from grave suffering for seriously ill people.
# People should have the autonomy to choose their own death, especially if they have a terminal disease, which challenges the notion of assisted suicide being a criminal act.
# Individuals suffering from painful medical conditions should have the right to opt for assisted suicide.
# Assisted suicide provides an avenue for terminally ill individuals to end their suffering.
# The right of patients to decide when to end their lives supports assisted suicide, challenging its criminalization.
# id: 2  k-means: 5
# Homeschooling may not guarantee high-quality education.
# Homeschooling should be banned because it does not provide children with the necessary social and cooperative skills needed for life.
# Homeschooling may result in substandard education if the parents lack intellectual capacity to teach.
# Homeschooling may hinder children's social development and interaction with peers.
# Lack of regulations in homeschooling could lead to gaps in students' education.
# id: 3  k-means: 5
# Homeschooling allows individualized learning and skill development in children.
# Some argue that homeschooling should not be banned as it provides parents the opportunity to choose what they believe is the best educational option for their children.
# Parents' right to decide on their children's education supports homeschooling.
# Homeschooling provides a better learning environment for children who find it difficult to learn in traditional classrooms.
# Homeschooling serves as a suitable alternative for children who struggle in traditional school settings.
# id: 4  k-means: 5
# The vow of celibacy can lead to desperate and inappropriate behaviors due to denial of natural instincts.
# The requirement of celibacy discourages capable people from joining the clergy.
# The vow of celibacy is outdated and irrelevant in contemporary society.
# The vow of celibacy contradicts natural urges, potentially leading to issues for those who struggle to maintain it.
# The vow of celibacy might contribute to cases of sexual abuse within the Catholic church.
# id: 5  k-means: 5
# The vow of celibacy is a personal choice and should not be abandoned.
# Celibacy can provide empowerment in certain situations and should not be discarded.
# The tradition and historical significance of the vow of celibacy.
# Celibacy tradition is seen as a means for priests to dedicate themselves completely to the church.
# Divinity and spirituality are reasons for upholding the vow of celibacy.
# id: 6  k-means: 5
# Marriage is unnecessary for lifelong companionship and commitment.
# Marriage is viewed as an outdated patriarchal tradition that is incompatible with modern societies.
# The increasing rates of divorce and separation are reasons to consider abandoning the institution of marriage.
# Abandoning marriage could result in significant financial savings, given the high costs associated with marriage and divorce.
# Marriage is perceived as an outdated concept lacking value in contemporary relationships.
# id: 7  k-means: 5
# Abandoning marriage could contribute to societal breakdown.
# Marriage is valued for its religious significance and the stability and family values it provides.
# Marriage contributes to emotional and financial stability for children.
# Abandoning marriage would take away a fundamentally important choice from individuals who wish to marry for various personal or protective reasons.
# Marriage is a sacred bonding between two people and maintains traditional beliefs, hence it should not be abandoned.
# id: 8  k-means: 5
# School uniforms can be expensive and are not financially accessible for all families.
# School uniforms restrict students' individuality and self-expression.
# School uniforms impose additional financial strain on parents due to their high cost and limited availability.
# School uniforms restrict the students' ability to express themselves, potentially hindering their personal development.
# School uniforms restrict students' freedom of expression.
# id: 9  k-means: 5
# School uniforms promote equality and reduce competition among students.
# The use of school uniforms helps prevent bullying related to fashion and clothing inequality among students.
# School uniforms contribute to a more efficient learning environment by reducing distraction related to students' attire.
# School uniforms promote unity and foster a sense of belonging among students.
# School uniforms may reduce bullying related to clothing brands.
# id: 10  k-means: 5
# Capital punishment is not a successful deterrent to crime.
# The risk of executing innocent people due to the fallibility of the justice system is a strong reason to abolish capital punishment.
# Capital punishment potentially suffers from social and racial bias, potentially being unjustly wielded against certain societal sections.
# Capital punishment goes against the sanctity of life and is an unjust sentencing for offenders.
# Capital punishment is inhumane and risks the execution of innocent individuals.
# id: 11  k-means: 5
# Capital punishment serves as a deterrent to serious crimes.
# Some people believe that capital punishment is the only effective consequence for those who commit heinous crimes.
# The necessity and effectiveness of capital punishment in dealing with grievous crimes.
# Capital punishment provides greater judicial discretion by expanding the range of potential punishments.
# Some argue that capital punishment is necessary as a deterrent for serious crimes.
# id: 12  k-means: 5
# Abolishing intellectual property rights can foster innovation and creativity by eliminating ownership concerns.
# Intellectual property rights promote monopoly of large corporations over creators' designs and work, hence their abolishment is necessary.
# Intellectual property rights create monopolies for large corporations, hindering free market competition.
# Intellectual property rights hinder the sharing of ideas.
# The difficulty in monitoring and tracking intellectual property rights justifies their abolition.
# id: 13  k-means: 5
# Abolishing intellectual property rights could hinder innovation and development due to lack of motivation.
# Intellectual property rights are necessary for safeguarding individuals' creations.
# Intellectual property rights are essential as they provide protection for individuals' hard work and innovations, ensuring their ideas are not stolen or misused by others.
# Intellectual property rights serve as protection for individuals' inventions and discoveries.
# Intellectual property rights are essential as they reward and protect the hard work of creators.
# id: 14  k-means: 5
# Abolishing the right to bear arms could reduce crime and murder levels by preventing unfit individuals from owning guns.
# The abolition of the right to keep and bear arms can reduce harm to innocent individuals.
# The increasing number of gun-related deaths indicates a need to abolish the right to keep and bear arms.
# The potential for weapons to be used in crime or personal vengeance is a strong reason for abolishing the right to keep and bear arms.
# The presence of firearms among civilians increases the chance of violent activities in societies.
# id: 15  k-means: 5
# The right to bear arms is essential for self defense and protection of property.
# Abolishing the right to keep and bear arms will leave citizens defenseless in situations where immediate help is unavailable.
# Some people believe that the right to keep and bear arms is necessary for self-defense.
# The necessity of firearms for self-defense.
# The right to keep and bear arms is a fundamental constitutional right that should not be abolished.
# id: 16  k-means: 5
# Adoption of an austerity regime can assist in decreasing government debt.
# Adopting an austerity regime can arrest the increase of national debt and guide the country towards financial stability.
# Adopting an austerity regime is necessary to prevent burdening future generations with our debt.
# The escalating national debt necessitates the adoption of an austerity regime for its reduction.
# An austerity regime is crucial during economic challenges.
# id: 17  k-means: 5
# Adopting an austerity regime could compromise citizens' health and welfare by reducing government spending on necessary support systems.
# Adoption of an austerity regime could negatively impact the poor.
# An austerity regime disproportionately affects vulnerable populations like the poor and sick.
# Austerity regimes can lead to increased unemployment due to reduction in government spending.
# Adopting an austerity regime by cutting social programs could negatively impact the poor's ability to contribute to the economy, causing broader adverse effects.
# id: 18  k-means: 5
# Adopting atheism could reduce conflicts and wars prompted by religious differences and minimize the imposition of beliefs on others.
# Adopting atheism could potentially reduce conflicts and wars associated with religious differences.
# atheism could halt religious conflicts by questioning the existence of god, which is mainly supported by unverifiable stories.
# Adopting atheism could be a logical response to the existence of evil and suffering in the world.
# Atheism promotes peace and eliminates prejudice associated with religious beliefs.
# id: 19  k-means: 5
# Some people believe in the value and comfort brought by embracing a higher power, which atheism denies.
# Religion provides personal comfort and freedom of belief, therefore atheism should not be enforced.
# Imposing atheism infringes on individual freedom of religious belief.
# Adopting atheism might create hostility and force of beliefs between atheists and religious people.
# Adopting atheism could lead to societal destruction as it implies a world without god.
# id: 20  k-means: 5
# Adopting libertarianism would promote greater freedom by reducing government interference in daily lives.
# Libertarianism enhances individual liberty and minimizes the oppressive nature of a large government.
# Libertarianism promotes personal freedom and limits government interference.
# Libertarianism will increase happiness by reducing government interference in individual decisions.
# Libertarianism supports individual freedom and autonomy, allowing people to live according to their own personal values and desires.
# id: 21  k-means: 5
# Libertarianism may overlook the benefits of collective action in addressing public needs.
# Libertarianism could lead to chaos due to the absence of sufficient rules and regulations.
# Libertarianism may lack adequate support for the economically disadvantaged, potentially leading to inequity in society.
# Libertarianism might lead to loss of social benefits and increase in crime rates.
# Adopting libertarianism could potentially result in excessive government control.
# id: 22  k-means: 5
# Human cloning could dangerously replace natural reproduction and potentially lead to societal downfall.
# Human cloning should be banned due to ethical concerns and its unnatural process.
# Human cloning is seen as unethical and against natural creation.
# The potential risks of creating defected humans or other harmful consequences support the ban on human cloning.
# Cloning humans presents serious ethical concerns and the potential for harmful genetic abnormalities due to limited understanding of gene manipulation.
# id: 23  k-means: 5
# Human cloning could contribute to significant advancements in medical research.
# The potential for scientific knowledge and advancement argues against a ban on human cloning.
# Human cloning can potentially solve genetic medical issues, thus it should not be banned.
# Human cloning could potentially contribute to medical breakthroughs in curing or eliminating diseases.
# Human cloning can potentially aid in discovering treatments for serious diseases.
# id: 24  k-means: 5
# Private military companies lack government regulation and can pose a risk to citizens within their own nation.
# Private military companies lack government regulation and can pose a risk to citizens within their own nation.
# Private military companies contribute to warfare rather than preventing it and hence should be banned.
# Private military companies are prone to corruption and could be exploited by rogue nations due to their focus on profit.
# The lack of oversight and potential for misconduct in private military companies necessitate their ban.
# id: 25  k-means: 5
# Private military companies are essential for equipping the military with necessary weapons and tools.
# Private military companies help reduce the burden on regular military forces.
# Private military companies can help in reducing government defense expenditure.
# Private military companies provide vital services to the armed forces and, therefore, should not be banned.
# Private military companies offer essential skills and support to the armed forces.
# id: 26  k-means: 5
# The premature exposure of child actors to adult issues such as drugs and sex is harmful and suggests the need for banning their participation until Hollywood provides a safe environment.
# Child actors face exploitation in the film industry and from their parents.
# Banning the use of child actors is necessary to ensure they receive a proper education.
# Child actors are denied the opportunity to experience a normal life.
# Child actors are susceptible to mental and sexual abuse, negatively impacting their life development.
# id: 27  k-means: 5
# Child actors should be allowed given proper regulations and protection, as acting can provide a financial head start for their future.
# Child actors should be allowed if they comprehend the associated risks.
# Banning child actors would negatively impact the realistic portrayal of children in TV shows and movies.
# Child actors are necessary to accurately depict child characters in movies and stories.
# Child actors can be financially beneficial for their future college costs and contribute positively to society with proper guidance.
# id: 28  k-means: 5
# The alleged inhumane treatment of prisoners at Guantanamo Bay detention camp is a reason for its closure.
# The Guantanamo Bay detention camp disregards human rights and due process through indefinite, extrajudicial detention.
# The Guantanamo Bay detention camp is a financial burden on taxpayers and unnecessary due to available facilities within the country.
# The Guantanamo Bay detention camp tarnishes the reputation and honor of the USA.
# The Guantanamo Bay detention camp should be closed due to the lack of fair trials for its detainees.
# id: 29  k-means: 5
# Keeping Guantanamo Bay detention camp open is necessary for global safety as it contains dangerous terrorists.
# Guantanamo Bay detention camp plays a crucial role in containing terrorists and criminals, allowing the government to gather intelligence and prevent terrorism.
# The Guantanamo Bay detention camp should remain open due to the risk posed by dangerous individuals held there.
# Guantanamo Bay detention camp is necessary for isolating dangerous criminals outside the US.
# The perception that Guantanamo Bay detention camp is a necessary facility for holding dangerous terrorists.
# id: 30  k-means: 5
# Affirmative action may result in discrimination by withholding opportunities from qualified individuals who are not from targeted minority groups.
# Affirmative action can potentially harm less privileged individuals instead of benefiting them, which defeats its purpose.
# Affirmative action causes discrimination against majority groups and limits their opportunities.
# Affirmative action is unnecessary if there's equal opportunity for all.
# Affirmative action unfairly gives opportunities based on personal characteristics unrelated to job performance, not merit.
# id: 31  k-means: 5
# Affirmative action provides opportunities to historically disadvantaged individuals.
# Affirmative action is necessary for correcting historical injustices against minorities.
# Some believe affirmative action is necessary to counter discrimination against minorities.
# Affirmative action is necessary to compensate for historical oppression and inequality faced by minorities.
# Ending affirmative action may lead to resumption of subtle discrimination against minorities.
# id: 32  k-means: 5
# Ending mandatory retirement can benefit the workforce as many older adults are still capable and productive.
# Mandatory retirement results in the loss of experienced employees which negatively impacts industries.
# Individuals should have the freedom to choose their retirement age, not be forced into it.
# Mandatory retirement is a form of age discrimination.
# Ending mandatory retirement promotes age inclusivity and gives individuals the freedom to work based on their capability, not age.
# id: 33  k-means: 5
# Mandatory retirement is beneficial in making room for younger job seekers and eliminating workers who may have reduced cognitive abilities due to old age.
# Mandatory retirement should be ended to create opportunities for younger individuals to join the workforce.
# Older age may result in decline in physical reflexes and mental sharpness.
# Mandatory retirement is beneficial to provide opportunities for younger generations and maintain productivity in the workforce.
# Mandatory retirement helps create job opportunities for younger generations.
# id: 34  k-means: 5
# Nuclear weapons are an existential threat to civilization.
# The risk and threat posed by nuclear weapons necessitates their abolition.
# Nuclear weapons are highly destructive and result in mass casualties, including innocent civilians and children, thus their abolition is necessary.
# The abolition of nuclear weapons would enhance global safety.
# The immense destructive capacity of nuclear weapons, capable of wiping out large populations, underscores the need for their abolition.
# id: 35  k-means: 5
# Nuclear weapons act as a deterrent to conflicts and wars between nations.
# The abolition of nuclear weapons might prompt nations to develop alternative weaponry for deterrence or offensive purposes.
# Some argue that nuclear weapons provide security and deterrence against attacks for nations.
# The perceived value of nuclear weapons as a deterrent to another world war.
# The user believes that nuclear weapons serve as deterrents, promoting peace among superpowers.
# id: 36  k-means: 5
# Urbanization negatively affects the environment, hence its adverse effects should be combated.
# Urbanization contributes significantly to environmental pollution.
# Urbanization leads to destruction of animal habitats and affects biodiversity.
# Urbanization leads to issues like overcrowding and increased pollution levels.
# The increase in urbanization leads to amplified poverty, pollution, overuse of resources like water and land, and health issues.
# id: 37  k-means: 5
# Urbanization creates better accessibility to vital services such as healthcare and education.
# Despite individuals' desires for improved job opportunities and amenities often found in urban areas, the continuous trend towards urbanization needs to be addressed.
# Urbanization is viewed as necessary to accommodate population growth.
# Urbanization posits better job opportunities for people.
# User claims that urbanization is necessary for economic growth and advancement.
# id: 38  k-means: 5
# Compulsory voting could increase voter turnout.
# Implementing compulsory voting will ensure higher voter participation, enhancing democracy by ensuring everyone's opinion is accounted for.
# Compulsory voting will increase political engagements and lead to fairer representation in government.
# Mandatory voting is essential for maintaining functional democracy.
# Compulsory voting ensures every citizen's participation and voice in elections.
# id: 39  k-means: 5
# Compulsory voting infringes on individual freedom of choice.
# Compulsory voting may lead to people casting uninformed votes if they are not genuinely interested or knowledgeable about the candidates or issues at hand.
# Mandatory voting infringes on the freedom of choice and may force people who lack strong political opinions to vote.
# Compulsory voting might result in uninformed votes, potentially leading to harmful political decisions.
# Compulsory voting contradicts the principle of freedom and personal choice in a democratic society.
# id: 40  k-means: 5
# Cannabis, being less harmful than legally available substances like alcohol and cigarettes, and having numerous medicinal benefits, should be legalized.
# Legalizing cannabis can provide pain relief for individuals suffering from various illnesses or disabilities, potentially being more effective than current medications.
# Legalizing cannabis could provide medical benefits for ill individuals.
# Cannabis is less harmful than certain legal substances and should therefore be legalized nationwide.
# Legalizing cannabis could free up significant law enforcement resources and is arguably less harmful than legal substances like alcohol.
# id: 41  k-means: 5
# Concerns about potential misuse and unknown harmful side effects support the argument against legalizing cannabis.
# Legalizing cannabis could potentially lead to the use of more dangerous drugs, as it's often seen as a gateway drug.
# Legalizing cannabis could potentially lead to increased use of more dangerous drugs.
# Legalizing cannabis can potentially lead to addiction to stronger drugs and mental health problems.
# Legalizing cannabis could potentially lead to the use of more harmful drugs and negatively affect mental health.
# id: 42  k-means: 5
# Legalizing prostitution can lead to a reduction in crime and improvements in health protection for sex workers by enabling better disease control measures.
# Legalizing prostitution could improve safety for sex workers and reduce criminal activities.
# Legalization of prostitution could improve safety for sex workers by allowing them to seek law enforcement protection.
# Legalizing prostitution respects adults' autonomy over their own bodies.
# Legalizing prostitution will empower sex workers by reducing the control of pimps and enabling them to assert their rights and needs.
# id: 43  k-means: 5
# Legalizing prostitution could potentially increase violence against women and children.
# Legalization of prostitution could potentially benefit exploiters and might lead to an increase in human trafficking.
# Legalization of prostitution could potentially increase immorality in society.
# Legalizing prostitution may normalize immoral behaviors such as selling and paying for sex.
# The query points to the belief that legalizing prostitution could contribute to the demoralization of women and should not be supported by the government.
# id: 44  k-means: 5
# Legalizing sex selection gives parents the freedom to decide the gender of their child.
# Legalizing sex selection could help in the prevention of transmission of gender-specific diseases to offspring.
# Legalizing sex selection could aid in maintaining a gender balance within families.
# Parents should possess the right to choose their child's gender.
# Legalizing sex selection provides families the freedom to choose the sex of their child, catering to their comfort and preparedness in raising a child.
# id: 45  k-means: 5
# Legalizing sex selection is unethical and goes against the natural course of life.
# Legalizing sex selection may lead to unethical manipulation of natural processes.
# Legalizing sex selection could lead to an imbalance between genders and societal implications such as a lack of suitable partners for future generations.
# Legalizing sex selection undermines the fundamental value and sanctity of life by allowing termination based on gender preference.
# Legalizing sex selection could lead to a gender imbalance.
# id: 46  k-means: 5
# The flag is a symbol of freedom and an American icon which should not be destroyed, hence flag burning needs to be prohibited.
# Flag burning is offensive and disrespectful to those who have served and sacrificed for the country.
# Flag burning can incite violence and unrest, which underscores the need to prohibit it.
# Flag burning is considered disrespectful and against the values and symbols of the nation.
# Flag burning should be prohibited because it offends people.
# id: 47  k-means: 5
# Flag burning is viewed as a form of free speech and expression.
# Flag burning is protected under the right to free speech by the First Amendment.
# Flag burning, despite its negative perception, should be protected as a freedom, considering it does not directly harm others.
# Flag burning is considered a form of freedom of speech and should be protected rather than prohibited.
# Prohibiting flag burning could infringe on freedom of speech rights.
# id: 48  k-means: 5
# Women may lack the physical strength and endurance required for combat roles.
# Women's natural physical strength is generally less than men's which might put them at a disadvantage in combat roles.
# The presence of women in combat zones alters male soldiers' behavior contrary to their training, risking the safety of units.
# Women's physical suitability for combat and their reproductive role for societal continuity are reasons to prohibit them from combat.
# The physical strength differences between men and women could hinder women's performance in combat.
# id: 49  k-means: 5
# Women have proven to be capable and effective in military roles, thus gender should not be a barrier in combat.
# Fitness and training, not gender, should be the primary criteria for combat roles.
# Women have the same capabilities as men and should not be prohibited from joining the military.
# Equal rights for women should extend to combat roles in the military.
# Women possess the same skills as men for effective combat performance.
# id: 50  k-means: 5
# Journalism plays a crucial role in keeping the public aware of significant matters.
# Subsidizing journalism is essential for supporting democracy through the provision of necessary information.
# Journalism requires government subsidization for its support.
# Subsidizing journalism can aid in developing a fresh market for information dissemination.
# Subsidizing journalism is essential for maintaining democracy as it keeps the public well-informed about global issues.
# id: 51  k-means: 5
# Subsidizing journalism could potentially reduce the quality due to oversaturation of journalists.
# Concerns about the financial viability of journalism without subsidies.
# Subsidizing journalism could lead to government control and potential bias in news reporting.
# Subsidizing journalism could risk government interference and undermine the independence of journalism.
# Journalism should remain independent and not receive subsidies from the government or other major institutions.
# id: 52  k-means: 5
# Subsidizing space exploration can accelerate important scientific discoveries.
# Subsidizing space exploration is critical for our understanding and safety in the universe.
# Space exploration leads to technological advancements and innovations beneficial to human life.
# Subsidizing space exploration is crucial for humanity's future survival as it offers alternatives when Earth becomes uninhabitable.
# Subsidizing space exploration could lead to discoveries of new resources beneficial for Earth.
# id: 53  k-means: 5
# Space exploration funding could be better used for addressing issues on Earth.
# Distributing resources for resolving existing global issues should take priority over subsidizing space exploration.
# Subsidizing space exploration is considered a misallocation of funds that could be better used elsewhere and should be funded by large space agencies.
# Opposition to subsidizing space exploration due to more pressing earth-based concerns.
# Space exploration is viewed as too expensive and not beneficial enough to warrant public funding.
# id: 54  k-means: 5
# Subsidizing vocational education can aid students in advancing their education and preparing for new career paths.
# Vocational education provides practical job training, particularly beneficial to those who may not be able to pursue traditional college education.
# Subsidizing vocational education could lead to better career preparation.
# Vocational education has the advantage of preparing individuals for employment.
# Subsidizing vocational education is essential as it facilitates the training for industries where workers are currently in high demand.
# id: 55  k-means: 5
# Subsidizing vocational education may lead to it having an unfair advantage over other career paths.
# Vocational education does not need subsidies because individuals trained in trades can potentially earn significantly.
# Opposition to specific subsidies for vocational education because all education should be equally supported through tuition.
# Subsidizing vocational education might detract funds from other socially beneficial initiatives.
# The subsidy should extend beyond vocational education to cover advanced education due to high costs.
# id: 56  k-means: 5
# Vaccinations are crucial for children to build immunity against various diseases.
# Mandatory vaccination for children ensures their protection against most infectious diseases.
# Mandatory routine child vaccinations are vital in preventing various diseases, thus guaranteeing a healthier future for the child.
# The user believes that routine child vaccinations should not only be mandatory but also provided for free globally.
# Mandatory child vaccinations can help prevent fatal diseases in children.
# id: 57  k-means: 5
# Concerns about potential side effects of vaccines on children argue against mandatory vaccinations.
# Mandatory vaccinations infringe on parental rights and freedom of choice.
# Concerns about potential side effects of child vaccinations.
# Some people believe vaccinations should not be mandatory because they question their validity and argue for personal choice.
# Parents should have the personal freedom to decide on their child's vaccinations.
# id: 58  k-means: 5
# Social media platforms should be regulated by the government to prevent crimes like scams.
# The need for government regulation of social media is emphasized due to the exposure of underage users to inappropriate content.
# The significant role of social networks in communication necessitates government regulation and legislation.
# Government regulation of social media platforms can help prevent criminal activities and their influence on others.
# Government regulation of social media platforms is necessary to prevent hate crimes and political disinformation.
# id: 59  k-means: 5
# Regulation of social media by the government can infringe on individual freedom of expression.
# Government regulation of social media platforms can threaten free speech and infringe on the autonomy of private businesses.
# Social media platforms should maintain freedom and not be controlled by any government.
# Regulation of social media by the government could potentially lead to suppression of criticism and free speech.
# Concerns about government intrusion and violation of privacy rights if they regulate social media platforms.
# id: 60  k-means: 5
# The USA offers a high quality of life and a robust economy.
# The USA provides abundant life opportunities for those who have the determination to succeed, reinforced by its capitalist economic system.
# The user appreciates the global influence of the US and considers it as an excellent place to live.
# The USA provides ample opportunities for personal and professional development.
# The USA is a desirable place to live due to its strong economic development.
# id: 61  k-means: 5
# The cost of healthcare and education for the middle class in the USA is high.
# The USA's high rate of mental illness could potentially challenge its status as a good country to live in.
# Concerns over potential racism and unequal treatment might impede perception of the USA as a good country to live in.
# The USA has significant racial issues to contend with.
# Concerns about gender inequality in the USA.

# %%
print(final_kps[0])
# Out:
# ['Assisted suicide may be exploited by people lacking mental capacity to understand its ultimate consequences, hence it should be criminalized.', 'Assisted suicide is equivalent to murder and should hence be considered a criminal offence.', 'Assisted suicide may be exploited by people lacking mental capacity to understand its ultimate consequences, hence it should be criminalized.', 'Assisting in suicide is equivalent to committing murder and should carry criminal charges.', 'Assisted suicide is a form of ending life and thus should be considered unlawful.']

# %%
df = pd.read_csv('./result/1by1+predictions_in_group.csv')
print(df)
print(len(final_kps))
# Out:
#                                                 topic  stance  \
# 0       Assisted suicide should be a criminal offence       1
# 1       Assisted suicide should be a criminal offence       0
# 2                      Homeschooling should be banned       1
# 3                      Homeschooling should be banned       0
# 4             The vow of celibacy should be abandoned       1
# ..                                                ...     ...
# 57     Routine child vaccinations should be mandatory       0
# 58  Social media platforms should be regulated by ...       1
# 59  Social media platforms should be regulated by ...       0
# 60               The USA is a good country to live in       1
# 61               The USA is a good country to live in       0
#
#                                             arguments  \
# 0   ["a cure or treatment may be discovered shortl...
# 1   ['`people reach their limit when it comes to t...
# 2   ['all children attending school ensures that t...
# 3   ['a parent knows best what is good for their k...
# 4   ['a vow of celibacy does nothing but cause iss...
# ..                                                ...
# 57  ['A vaccine that has not been sufficiently tes...
# 58  ['all social media platforms should be regulat...
# 59  ['Asking governments and institutions to be mo...
# 60  ['Along with the diversity of people, The Unit...
# 61  ['he state of anguish that many of the large c...
#
#                                            kep_points  predict_kps
# 0   ['Assisted suicide allows people to solicit so...          NaN
# 1   ['Assisted suicide gives dignity to the person...          NaN
# 2   ['Mainstream schools are essential to develop ...          NaN
# 3   ['Homeschooling is often the best option for c...          NaN
# 4   ['Celibacy is outdated', 'Celibacy is too pres...          NaN
# ..                                                ...          ...
# 57  ['Routine child vaccinations are not necessary...          NaN
# 58  ['Social media regulation protects the younger...          NaN
# 59  ['Social media regulation is not effective', '...          NaN
# 60  ['The US offers great opportunities for indivi...          NaN
# 61  ['The US has unfair health and education polic...          NaN
#
# [62 rows x 5 columns]
# 62

# %%
for index, value in enumerate(final_kps):
    df.at[index,'predict_kps'] = str(value)

print(df)
# Out:
#                                                 topic  stance  \
# 0       Assisted suicide should be a criminal offence       1
# 1       Assisted suicide should be a criminal offence       0
# 2                      Homeschooling should be banned       1
# 3                      Homeschooling should be banned       0
# 4             The vow of celibacy should be abandoned       1
# ..                                                ...     ...
# 57     Routine child vaccinations should be mandatory       0
# 58  Social media platforms should be regulated by ...       1
# 59  Social media platforms should be regulated by ...       0
# 60               The USA is a good country to live in       1
# 61               The USA is a good country to live in       0
#
#                                             arguments  \
# 0   ["a cure or treatment may be discovered shortl...
# 1   ['`people reach their limit when it comes to t...
# 2   ['all children attending school ensures that t...
# 3   ['a parent knows best what is good for their k...
# 4   ['a vow of celibacy does nothing but cause iss...
# ..                                                ...
# 57  ['A vaccine that has not been sufficiently tes...
# 58  ['all social media platforms should be regulat...
# 59  ['Asking governments and institutions to be mo...
# 60  ['Along with the diversity of people, The Unit...
# 61  ['he state of anguish that many of the large c...
#
#                                            kep_points  \
# 0   ['Assisted suicide allows people to solicit so...
# 1   ['Assisted suicide gives dignity to the person...
# 2   ['Mainstream schools are essential to develop ...
# 3   ['Homeschooling is often the best option for c...
# 4   ['Celibacy is outdated', 'Celibacy is too pres...
# ..                                                ...
# 57  ['Routine child vaccinations are not necessary...
# 58  ['Social media regulation protects the younger...
# 59  ['Social media regulation is not effective', '...
# 60  ['The US offers great opportunities for indivi...
# 61  ['The US has unfair health and education polic...
#
#                                           predict_kps
# 0   ['Assisted suicide may be exploited by people ...
# 1   ['Assisted suicide must not be a criminal offe...
# 2   ['Homeschooling may not guarantee high-quality...
# 3   ['Homeschooling allows individualized learning...
# 4   ['The vow of celibacy can lead to desperate an...
# ..                                                ...
# 57  ['Concerns about potential side effects of vac...
# 58  ['Social media platforms should be regulated b...
# 59  ['Regulation of social media by the government...
# 60  ['The USA offers a high quality of life and a ...
# 61  ['The cost of healthcare and education for the...
#
# [62 rows x 5 columns]

# %%
df.to_csv('./result/1by1+predictions_in_group.csv', index=False)
print("Add successfully.")
# Out:
# Add successfully.

# %%
f = open("./result/KP_generation_clustering.txt",'w', encoding='UTF-8')
for batch_id, topic in enumerate(ArgKP2021_topics):
    print(batch_id*2)
    print("-------------------Processing-------------------")
    f.write(str(batch_id*2)+"\n")
    f.write("topic: "+topic+"\n")
    f.write("\n")
    for sentence in final_kps[batch_id*2]:
        f.write(sentence+"\n")
    f.write("\n")
    f.write(str(batch_id*2+1)+"\n")
    f.write("topic: "+topic+"\n")
    f.write("\n")
    for sentence in final_kps[batch_id*2+1]:
        f.write(sentence+"\n")
    f.write("\n")

print("-----------------Finished--------------------------")
# Out:
# 0
# -------------------Processing-------------------
# 2
# -------------------Processing-------------------
# 4
# -------------------Processing-------------------
# 6
# -------------------Processing-------------------
# 8
# -------------------Processing-------------------
# 10
# -------------------Processing-------------------
# 12
# -------------------Processing-------------------
# 14
# -------------------Processing-------------------
# 16
# -------------------Processing-------------------
# 18
# -------------------Processing-------------------
# 20
# -------------------Processing-------------------
# 22
# -------------------Processing-------------------
# 24
# -------------------Processing-------------------
# 26
# -------------------Processing-------------------
# 28
# -------------------Processing-------------------
# 30
# -------------------Processing-------------------
# 32
# -------------------Processing-------------------
# 34
# -------------------Processing-------------------
# 36
# -------------------Processing-------------------
# 38
# -------------------Processing-------------------
# 40
# -------------------Processing-------------------
# 42
# -------------------Processing-------------------
# 44
# -------------------Processing-------------------
# 46
# -------------------Processing-------------------
# 48
# -------------------Processing-------------------
# 50
# -------------------Processing-------------------
# 52
# -------------------Processing-------------------
# 54
# -------------------Processing-------------------
# 56
# -------------------Processing-------------------
# 58
# -------------------Processing-------------------
# 60
# -------------------Processing-------------------
# -----------------Finished--------------------------

# %%
import ast
test_df = pd.read_csv('./result/1by1+predictions_in_group.csv')
prediction = test_df['predict_kps'].values.tolist()
a = ast.literal_eval(prediction[0])
print(a[4])
# Out:
# Assisted suicide is a form of ending life and thus should be considered unlawful.
